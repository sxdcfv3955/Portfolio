# %%
import pandas as pd
import os.path, glob
import re

# %%
def Preprocessing_Confirmer() : 
    df = pd.read_csv("../data/대륙데이터.csv")
    
    df['Date'] = df['Date'].apply( lambda x : int(x.replace('-', '')))
    
    China_df = df[ df['Continent'] == 'China' ]
    Asia_df = df[ df['Continent'] == 'Asia' ]
    Africa_df = df[ df['Continent'] == 'Africa' ]
    America_df = df[ df['Continent'] == 'America' ]
    Europe_df = df[ df['Continent'] == 'Europe' ]
    Oceania_df = df[ df['Continent'] == 'Oceania' ]
    Etc_df = df[ df['Continent'] == 'Etc' ]
    
    China_group_df = China_df.groupby(China_df['Date']).sum()
    Asia_group_df = Asia_df.groupby(Asia_df['Date']).sum()
    Africa_group_df = Africa_df.groupby(Africa_df['Date']).sum()
    America_group_df = America_df.groupby(America_df['Date']).sum()
    Europe_group_df = Europe_df.groupby(Europe_df['Date']).sum()
    Oceania_group_df = Oceania_df.groupby(Oceania_df['Date']).sum()
    Etc_group_df = Etc_df.groupby(Etc_df['Date']).sum()
    
    China_group_df.to_csv('../data/Confirmer/China_group_df.csv', index=False)
    Asia_group_df.to_csv('../data/Confirmer/Asia_group_df.csv', index=False)
    Africa_group_df.to_csv('../data/Confirmer/Africa_group_df.csv', index=False)
    America_group_df.to_csv('../data/Confirmer/America_group_df.csv', index=False)
    Europe_group_df.to_csv('../data/Confirmer/Europe_group_df.csv', index=False)
    Oceania_group_df.to_csv('../data/Confirmer/Oceania_group_df.csv', index=False)

# %%
def Preprocessing_Entry() : 
    df = pd.read_excel('../data/해외입국자.xlsx')
    
    df.columns = ['Date', 'Sum', 'China', 'Asia', 'Europe', 'America', 'Africa', 'Oceania', 'total' ]
    
    df['Date'] = df['Date'].apply(lambda x : int( str(x).replace('-','').replace(' 00:00:00','')))
    
    df.sort_index(ascending=False, inplace=True)
    
    China_df = df[ ['Date', 'China'] ]
    Asia_df = df[ [ 'Date', 'Asia' ] ]
    Europe_df = df[ [ 'Date', 'Europe' ] ]
    America_df = df[ [ 'Date', 'America' ] ]
    Africa_df = df[ [ 'Date', 'Africa' ] ]
    Oceania_df = df[ [ 'Date', 'Oceania' ] ]
    
    China_df.to_csv('../data/Entry/China_group_df.csv', index=False)
    Asia_df.to_csv('../data/Entry/Asia_group_df.csv', index=False)
    America_df.to_csv('../data/Entry/America_group_df.csv', index=False)
    Africa_df.to_csv('../data/Entry/Africa_group_df.csv', index=False)
    Europe_df.to_csv('../data/Entry/Europe_group_df.csv', index=False)
    Oceania_df.to_csv('../data/Entry/Oceania_group_df.csv', index=False)

# %%
def ICAO_code( x ) : 

    if ( x[-5] == 'A' or x[-5] == 'O' or x[-5] == 'R' or x[-5] == 'V' or x[-5] == 'W') : 
        return 'Asia' 

    elif ( x[-5] == 'B' or x[-5] == 'E' ) : 
        return 'Europe'

    elif ( x[-5] == 'D' or x[-5] == 'F' or x[-5] == 'H' ) : 
        return 'Africa'

    elif ( x[-5] == 'C' or x[-5] == 'K' or x[-5] == 'M') :
        return 'America' 
    
    elif x[-5] == 'Y' :
        return 'Oceania' 
    
    elif x[-5] == 'G' : 
        if x[-4] == 'C' or x[-4] == 'E': 
            return 'Europe'
        else :
            return 'Africa'
            
    elif x[-5] == 'L' : 
        if x[-4] == 'L' or x[-4] == 'V' : 
            return 'Asia'
        else :
            return 'Europe'
            
    elif x[-5] == 'N' : 
        if x[-4] == 'L' or x[-4] == 'W' or x[-4] == 'T' : 
            return 'Europe'
        else :
            return 'Oceania'
            
    elif x[-5] == 'P' : 
        if x[-4] == 'T' : 
            return 'Asia'
        else :
            return 'America'
            
    elif x[-5] == 'S' : 
        if x[-4] == 'F' or x[-4] == 'O' : 
            return 'Europe'
        else :
            return 'America'
            
    elif x[-5] == 'T' : 
        if x[-4] == 'F' or x[-4] == 'N' or x[-4] == 'Q' or x[-4] == 'R' or x[-4] == 'U' or x[-4] == 'X': 
            return 'Europe'
        else :
            return 'America'
    
    elif x[-5] == 'U' : 
        if x[-4] == 'A' or x[-4] == 'T' or x[-4] == 'B' or x[-4] == 'D' or x[-4] == 'G' or x[-4] == 'T': 
            return 'Asia'
        else :
            return 'Europe'
        
    elif x[-5] == 'Z' :
        if x[-4] == 'K' or x[-4] == 'M' : 
            return 'Asia'
        else :
            return 'China'
        
    else :
        return x

# %%
def Preprocessing_Flight() : 
    column = ['공항', '노선', '항공사','운항_출발', '운항_도착', 
          '운항_계', '여객_출발', '여객_도착', '여객_계', '화물_출발', '화물_도착', '화물_계' ]
    
    df = pd.DataFrame(columns=column)
    
    airport_path_list = glob.glob( '../data/공항/*' )

    for airport in airport_path_list : 
        file_path_list = glob.glob(airport + '/*')

        for path in file_path_list : 
            file_list = glob.glob(path + '/*')

            for file in file_list : 
                filename = os.path.basename( file )
                print(filename)

                tmp_df = pd.read_excel(file, header=3)
                tmp_df.drop( tmp_df.columns[0] , axis=1, inplace=True )
                tmp_df.columns = column

                p = re.compile('[^0-9]')
                date =  p.sub( '' , filename )
                tmp_df['날짜'] = date

                df = pd.concat([df,tmp_df])

        df.reset_index(inplace=True)
        df.drop(df.columns[0] , axis=1, inplace=True)
        df.to_csv('../data/공항/'+filename[:4]+'.csv', index=False)     
        df = pd.DataFrame(columns=column)
        
    df_Gimpo    = pd.read_csv("../data/공항/김포공항.csv")
    df_GimHae   = pd.read_csv("../data/공항/김해공항.csv")
    df_Daegu    = pd.read_csv("../data/공항/대구공항.csv")
    df_Muan     = pd.read_csv("../data/공항/무안공항.csv")
    df_Yangyang = pd.read_csv("../data/공항/양양공항.csv")
    df_Incheon  = pd.read_csv("../data/공항/인천공항.csv")
    df_Jeju     = pd.read_csv("../data/공항/제주공항.csv")
    df_Cheongju = pd.read_csv("../data/공항/청주공항.csv")
    
    df = pd.concat( [ df_Gimpo, df_GimHae, df_Daegu, df_Muan, 
                 df_Yangyang, df_Incheon, df_Jeju, df_Cheongju ] )
    
    df.reset_index(inplace=True)
    df.drop('공항', axis=1, inplace=True)
    df.drop('항공사', axis=1, inplace=True)
    
    df['노선'] = df['노선'].apply( lambda x : ICAO_code( x ) )
    df.drop('index', axis=1, inplace=True)
    
    df.columns = ['Flight_Country', 'Flight_departure', 'Flight_arrivals', 'Flight_total', 
                                  'Passenger_departure', 'Passenger_arrivals', 'Passenger_total',
                                  'Freight_departure', 'Freight_arrivals', 'Freight_total', 'Date']
    
    Asia_df    = df[ df['Flight_Country'] == 'Asia' ]
    China_df   = df[ df['Flight_Country'] == 'China' ]
    Europe_df  = df[ df['Flight_Country'] == 'Europe' ]
    America_df = df[ df['Flight_Country'] == 'America' ]
    Africa_df  = df[ df['Flight_Country'] == 'Africa' ]
    Oceania_df  = df[ df['Flight_Country'] == 'Oceania' ]
    
    Asia_df.drop('Flight_Country', axis=1, inplace=True)
    China_df.drop('Flight_Country', axis=1, inplace=True)
    Europe_df.drop('Flight_Country', axis=1, inplace=True)
    America_df.drop('Flight_Country', axis=1, inplace=True)
    Africa_df.drop('Flight_Country', axis=1, inplace=True)
    Oceania_df.drop('Flight_Country', axis=1, inplace=True)
    
    Asia_group_df    = Asia_df.groupby(Asia_df['Date']).sum()
    China_group_df   = China_df.groupby(China_df['Date']).sum()
    Europe_group_df  = Europe_df.groupby(Europe_df['Date']).sum()
    America_group_df = America_df.groupby(America_df['Date']).sum()
    Africa_group_df  = Africa_df.groupby(Africa_df['Date']).sum()
    Oceania_group_df  = Oceania_df.groupby(Oceania_df['Date']).sum()
    
    Asia_group_df.to_csv('../data/Airport/Asia_group_df.csv', index=False)
    China_group_df.to_csv('../data/Airport/China_group_df.csv', index=False)
    Europe_group_df.to_csv('../data/Airport/Europe_group_df.csv', index=False)
    America_group_df.to_csv('../data/Airport/America_group_df.csv', index=False)
    Africa_group_df.to_csv('../data/Airport/Africa_group_df.csv', index=False)
    Oceania_group_df.to_csv('../data/Airport/Oceania_group_df.csv', index=False)

# %%
def Preprocessing_News() : 
    df = pd.read_csv('../data/P_N_rate.csv')
    
    China_group_df = China_df.groupby(China_df['Date']).sum()
    Asia_group_df = Asia_df.groupby(Asia_df['Date']).sum()
    America_group_df = America_df.groupby(America_df['Date']).sum()
    Africa_group_df = Africa_df.groupby(Africa_df['Date']).sum()
    Europe_group_df = Europe_df.groupby(Europe_df['Date']).sum()
    Oceania_group_df = Oceania_df.groupby(Oceania_df['Date']).sum()
    
    China_group_df.to_csv('../data/News/China_group_df.csv', index=False)
    Asia_group_df.to_csv('../data/News/Asia_group_df.csv', index=False)
    America_group_df.to_csv('../data/News/America_group_df.csv', index=False)
    Africa_group_df.to_csv('../data/News/Africa_group_df.csv', index=False)
    Europe_group_df.to_csv('../data/News/Europe_group_df.csv', index=False)
    Oceania_group_df.to_csv('../data/News/Oceania_group_df.csv', index=False)

# %%
def code( x ) : 
    China_port = ['XIAMEN','TAICANG','NINGBO','SHANGHAI','QINGDAO PT','CAOJING','BAYUQUAN','CHANGSHU','ZHENJIANG PT',
              'LIANYUNGANG','ZHANGJIAGANG','ZHAPU','QINGDAO','DANDONG PT','SHIDAO PT','YANTAI','YANTIAN PT',
              'TIANJIN','JINGTANG(TANGSHAN)','DALIAN','ZHOUSHAN PT','NANTONG PT','QINHUANGDAO PT','TAIXING','NANJING',
              'WEIHAI','JINZHOU PT','WAIGAOQIAO PT','LONGKOU PT','CHANGSHU PT','JIANGYIN PT','HUANGHUA PT','RUGAO PT',
              'CAOFEIDIAN PT','LANSHAN PT','ZHAPU PT','DONGYING PT','RIZHAO PT','TIANJIN XINGANG PT','BEIHAI PT','WEIFANG PT',
              'ZHANJIANG','SHEKOU PT','SHANTOU','NINGDE','DONGGUAN PT','NANSHA PT','LONGYAN PT','LAIZHOU PT','TAIZHOU',
              'YANTAI PT','WEIFANG','JINGJIANG','FUJIN','JIUZHOU PT','NINGBO PT','YINGKOU PT','JIANGYIN','SHANGHAI PT',
              'CHANGZHOU PT','JINGTANG PT','DA CHAN BAY','FUZHOU','Qidong Pt','XINGANG','PENGLAI','NANJING PT',
              'YANGZHOU PT','YANGSHAN','HUANGHUA','PANJIN','DONGYING','LAIZHOU','JINGJIANG PT','DAFENG PT','FUZHOU PT',
              'YIZHENG','ZHANGZHOU PT','HUANGPU PT','DAYAOWAN','CHANGZHOU, JIANGAU','DAGANG','DONGJIANGKOU','LU-HUA SHAN',
              'JIAXING','QUANZHOU PT','TAICANG PT','QINZHOU PT','JINSHAN','BAOSHAN PT','SHEKOU (CODE CHANGE CN SHK))',
              'HULUDAO PT','GUANGZHOU','DAFENG','TANGSHAN','XINHUI PT','PENGLAI PT','TIANJIN PT','SONGXIA PT','FANGCHENG PT',
              'QIANWAN','HAIKOU','RONGCHENG','TAIZHOU PT','WENZHOU PT','JIAXING PT','ZHANJIANG PT','XIAOHUDAO','CHENGXI',
              'LUSHUN NEW PT','HUIZHOU PT','LUANJIAKOU','MAANSHAN PT','CHINA/MACHONG','XIUYU','XIAMEN PT','MAOMING','BASUO',
              'CHENJIAGANG','GUANGZHOU PT','GULEI','DALIAN PT','WUHU PT','FUQING','WEIHAI PT','DANDONG','HUMEN PT','YANGPU PT',
              'PUTIAN','QUANZHOU','SHANTOU PT','ZHUHAI PT','SHENZHEN','SANBAIMEN','TONGLING PT','DEFENG','HAIYANG','WENZHOU',
              'HAIMEN','LUOYANG','ZHENHAI PT','YANGJIANG PT','JINGZHOU PT','CHONGMING','HUANGPU NEW PORT','TANGSHAN PT',
              'XINSHA','MAJI SHAN' ]

    Asia_port = ['NEGHISHI/YOKOHAMA','SHIMONOSEKI','KOBE','OITA','FUKUYAMA, HIROSHIMA','NANAO',
                 'AKITA','IMABARI','HAKATA/FUKUOKA','TOYAMA','MIZUSHIMA','KIKUMA','SENDAI, MIYAGI',
                 'NIIGATA','YOKOHAMA','OSAKA','IYOMISHIMA','WAKAMATSU/KITAKYUSHU','TSUKUMI','SAKAI',
                 'MOJI/KITAKYUSHU','TOYOHASHI','HIROSHIMA','TOKUYAMA','HIBIKINADA, FUKUOKA','SAKAIDE',
                 'WAKAYAMA','KUSHIRO','IZUHARA','HITAKATSU','YOKKAICHI','NAOSHIMA','SHIMOTSU',
                 'HIGASHIHARIMA','KINUURA','ISHIKARIWAN-SHINKO, HOKKAIDO','SHIMIZU','CHOFU','FUNABASHI',
                 'RUMOI','MATSUYAMA','MURORAN','NAGASAKI','TSURUGA','NAGOYA, AICHI','TOMAKOMAI',
                 'KAKOGAWA','KUROSAKI','HITACHINAKA','KUDAMATSU','HIGASHI-OGISHIMA','HACHINOHE',
                 'KANAZAWA','TOKYO','MISUMI, SHIMANE','IMARI','IWAKUNI','UBE','KASHIMAE','MITAJIRI',
                 'KAWASAKI','SAKATA','OKINAWA, OKINAWA','HOSOSHIMA','ITOZAKI','SAKAIMINATO','OTAKE'
                 'UWAJIMA','YATSUSHIRO','SUSAKI','SATSUMASENDAI','KIIRE','KOMENOTSU','ETAJIMA','ARIAKE, TOKYO',
                 'KASHIMA, IBARAKI','ISHIKARI','KIMITSU','NAHA, OKINAWA','HAKODATE','WAKAMATSU, NAGASAKI',
                 'HIMEKAWA','MUTSURE','OSHIMA, NAGASAKI','REIHOKU','MATSUURA, NAGASAKI','TOYAMASHINKO',
                 'SENZAKI','JAPAN ODAIBA','KURE, HIROSHIMA','OURA/ARIAKE','NIIHAMA','YAMAGUCHI','ONAHAMA',
                 'SHIKAMA','MATSUSHIMA, NAGASAKI','KATAKAMI','KASHIMA, SAGA','SAKAISENBOKU','HINASE',
                 'FUKUYAMA, KAGOSHIMA','SAIGO, SHIMANE','HAMADA','KAWANOE','NAOETSU','NADAHAMA',
                 'TOUYO','NAGOYA, OITA','HITACHI','YAWATA, FUKUOKA','SASEBO','ONOMICHI','NOSHIRO',
                 'HIRO','KUMAMOTO','KAGOSHIMA','MAIZURU','ISHINOMAKI','KOKURA','TAKASAGO','MISUMI', 
                 'KUMAMOTO','TAKUMA','ICHIHARA','SHIMABARA','FUSHIKI','KAJIKI','TAGONOURA','OMAEZAKI'
                 'NAKANOSEKI','SODEGAURA','MIIKE, TOKYO','HIMEJI','ICHIKAWA','TAMASHAIMA','SAGANOSEKI',
                 'SHIBUSHI','AOMORI','MISHIMA, KAWANOE','TOBATA, FUKUOKA','TACHIBANA','MIHARA','CHITA',
                 'OKI','KISHIWADA','MIYAKO, IWATE','ONODA','SENDAISHIOGAMA','NAMIKATA','SHINMOJI','MIYAZU',
                 'MATSUNAGA','KURE, KOCHI','SHIGEI','SAIKI','TOKUSHIMA','AMAGASAKI','MAKURAZAKI','KASADO',
                 'IWAGI,EHIME','TATSUGO','USUKI','TADOTSU','NAGAHAMA, EHIME','MIIKE, FUKUOKA','TAKAMATSU',
                 'HIROTA, IWATE','MIYAZAKI, MIYAZAKI','TSUSHIMA, NAGASAKI','TAHARA','AIOI','HIKARI','NAKAGUSUKU',
                 'YOKOSUKA','HIDAKA','TSURUMI, KANAGAWA','HIKOSHIMA','HIZENOHSHIMA','MATSUURA, KAGOSHIMA',
                 'HABU, HIROSHIMA','FUKUOKA, FUKUOKA','NUMAZU','KASHIWAZAKI','KITANADA','NIIGATAHIGASHI',
                 'KANDA, FUKUOKA','TAKAHAMA/AMAKUSA','NANYO, YAMAGUCH','SHIMOJISHIMA, OKINAWA',
                 'HIAGARI/KITAKIUSHU','ONISHI','TANIYAMA','JOETSU','SAKURAJIMA','HIROHATA','HIRARA','YUSU',
                 'USHIBUKA','HAKATASHIMA','FUTAJIMA, FUKUOKA','FUKUSHIMA, MIYAZAKI','NAGASU, KUMAMOTO',
                 'OHGISHIMA','YAWATAHAMA','NOBEOKA','MINAMATA','TSUNEISHI','ISHIGAKI','OHIGAWA','NANKO',
                 'KYOTO, KYOTO','ONOMICHIITOZAKI','KINOE','KINNAKAGUSUKU',
                 'MAI-LIAO','AN PING','SUAO','KAOHSIUNG','TAIPEI','TAICHUNG','KAINAN','KEELUNG (CHILUNG)','HUALIEN',
                 'SON DUONG','VUNG TAU','PHUOC LONG','CAI LAN','HO CHI MINH CITY','VAN PHONG','DA NANG'
                 'SAI GON PT','HONGAI','GO DAU A TERMINAL','PHU MY','DONG NAI','CAM PHA','HAIPHONG','NGHI SON',
                 'CHAN MAY PORT','CAI MEP INTERNATIONAL TERMINAL','VINH','HO CHI MINH, VICT','QUI NHON','FUKUI',
                 'CAMRANH','DUNG QUAT','GO DAU B TERMINAL','HONG KONG','VICTORIA',
                 'TARAKAN, KALIMANTAN','TANJUNG BARA, KL','BITUNG, SULAWESI','ANYER KIDUL','SAMARINDA, KALIMANTAN',
                 'BALIKPAPAN','AMAMAPARE, IJ','PADANG','TABONEO','JAKARTA, JAVA','ADANG BAY','PELABUHAN FUTONG',
                 'PANJANG','BONTANG, KL','LUWUK','GRESIK, JAVA','PENGGARANG/TANJ.PENGILEH','POSO, SULAWESI','MUARA PANTAI',
                 'BANJARMASIN','Bunati','BINTUNI','DUMAI, SUMATRA','TARJUN','CIGADING, JV','MUARA BERAU','MERAK, JAVA',
                 'PALEMBANG, SUMATRA','SURABAYA',"JAMBI, SUMATRA",'SATUI','TONDA','BANGGAI','KUMAI','KUALA ENOK',
                 'PONTIANAK, KALIMANTAN','CILEGON','BENOA, BALI','SUNGAI PAKNING, SUMATRA','TANJONG BIN',
                 'DAVAO, MINDANAO','BATANGAS/LUZON','ROXAS/PUERTO PRINCESA','LIMAY/BATAAN','MANILA SOUTH HARBOUR'
                 'MANILA','BATAAN, MARIVELES','BALOGO/BATANGAS','ILIGAN, MINDANAO','PORO','CULAO','CALAPAN/BATANGAS'
                 'ALBUERA','PAMPLONA/APARRI','CAVITE, LUZON','BACON/LEGASPI','HIBI','SUBIC BAY','GENERAL SANTOS',
                 'CAGAYAN DE ORO, MINDANAO','CEBU','BOGO/CAGAYAN DE ORO','Calaca','LEGASPI APT, LUZON','JASAAN/CAGAYAN DE ORO',
                 'BACOLOD, NEGROS','BASRA','UMM QASR','GALLE','COLOMBO','RAS TANURA',
                 'YANBU AL-BAHR','RAS AL KHAIR', 'JUAYMAH TERMINAL','AD DAMMAM','JUBAIL',
                 'QALHAT','MIN-AL-FAHAL','SALALAH',	'SINGAPORE','JURONG','AL FUJAYRAH','RUWAIS','KHOR AL FAKKAN',
                 'DAS ISLAND','JEBEL ALI','ZURKU ISLAND','OFFSHORE FUJAIRAH','RAS LAFFAN','LAHAD DATU, SABAH',
                 'LUMUT','LABUAN, SABAH','LINGGA, SARAWAK','PORTKELANG','BINTULU, SARAWAK','TANJUNG PELEPAS',
                 'TAWAU, SABAH','WESTPORT/PORT KLANG','KERTEH TERMINAL','SANDAKAN, SABAH','KUNAK, SABAH',
                 'SUNGAI RENGIT','KIMANIS, SABAH','MALACCA','PASIR GUDANG, JOHOR',"MIRI, SARAWAK",'KEMAMAN',
                 'KOTA KINABALU, SABAH','SERIA','TANJUNG LANGSAT','MAKASSAR','MINA AL AHMADI','MINA ABD ALLAH',
                 'KUWAIT','SITRAH','PHITSANULOK','LAEM CHABANG','KHANOM','KOH SICHANG','SATTAHIP','SIAM BANGKOK PORT','RAYONG',
                 'BANGKOK','BAN MAP TA PHUT','SHARK BAY','SRIRACHA','PARADIP GARH','VISAKHAPATNAM','KOCHI',
                 'COCHIN','CHENNAI (EX MADRAS)','SIKA','NIPAH','NEW MANGALORE','TUTICORIN','PIPAVAV (VICTOR) PORT',
                 'KANDLA','VIZAGAPATANAM','MUMBAI (EX BOMBAY)','MUARA']

    Oceania_port=['KOROR','POHNPEI (EX PONAPE)','LAUTOKA','SUVA','VUDA','PORT MORESBY','RABAUL','NAKETY','NOUMEA','TEOUDIE',
                  'NEPOUI','KOUAOUA','TARAWA','FUNAFUTI','NORO, NEW GEORGIA','HONIARA, GUADALCANAL IS','TIMARU','TAURANGA',
                  'PICTON','BLUFF','DUNEDIN','NEDERLAND, CO','MARSDEN POINT','ASHBURTON','NAPIER','WELLINGTON','PORT CHALMERS',
                  'AUCKLAND','BRISBANE','GLADSTONE','DARWIN','PORT HEDLAND','BARROW ISLAND','GROOTE EYLANDT','WYNDHAM',
                  'PORT WALCOTT','BOTANY BAY','ABBOT POINT','CAIRNS','ONSLOW','DAMPIER','KWINANA','GEELONG','GISBORNE',
                  'USELESS LOOP','MACKAY','FREMANTLE','HAY POINT','MATSUURA, OITA','GERALDTON','NELSON',
                  'ISABEL','SUNRISEBEACH','DALRYMPLE ISLET','ALBANY','DEVONPORT','WESTERNPORT','CAPE FLATTERY','BURNIE',
                  'PORT DALRYMPLE','KIMBE','BARROW ISLAND, WA','BING BONG','PORT KEMBLA','GOVE','CAPE CUVIER',
                  'MASCOT','MOURILYAN','BUNBURY','SYDNEY','MELBOURNE','NEWCASTLE','MAJURO','KWAJALEIN','EBEYE','MARSHALL']

    Europe_port = ['PAPEETE','BERGEN','CONSTANTA',
                   'NOVOROSSIYSK', 'VLADIVOSTOK', 'NAKHODKA', "BUKHTA OL'GA", 'PETROPAVLOVSK-KAMCHATSKIY','KHOLMSK',
                   'VOSTOCHNYY PORT','ZARUBINO','VANINO','SLAVYANKA','DE-KASTRI','PRIGORODNOYE',"YUZHNO-KURIL'SK",'PLASTUN',
                   'OKHOTSK','KORSAKOV','KOZMINO PORT','MAGADAN','TUAPSE','POSYET','SEVERO-KURILSK','MAGADANSKY, PORT',
                   'SOVETSKAYA GAVAN','KAVKAZ','SHAKHTERSK' ]

    America_port = ['OCEAN DISTRICT','BALBOA','SEATTLE','BEAUMONT, TX','ROBERTS BANK','CRISTOBAL','VANCOUVER','OAKLAND, CA',
                    'LONGBEACH','PORTLAND, OR','SANDIEGO','HONOLULU','CAYO ARCAS TERMINAL','MANZANILLO','PORT MELLON','BAHIA BLANCA',
                    'NORTH PACIFIC OCEAN','TROIS-RIVIERES (THREE RIVERS)','LOSANGELES','TACOMA',
                    'CALLAO','FREDERICKTOWN','MATANE','CANAL','ANTOFAGASTA','CLATSKANIE','CORPUSCHRISTI','ALBANY, NY','GALVESTON',
                    'WOODRIVER','PANAMA, CIUDAD DE','KALTAG','OREGON','LIRQUEN','NECOCHEA','LA LIBERTAD','PORTMANATEE','HOUSTON, TX',
                    'PONTA DA MADEIRA','TOWNSVILLE','MATARANI','GRAYSHARBORCITY','POINT LISAS','ITAGUAI','ANCHORAGE','RODMAN','PISCO',
                    'MINE','STEWART','COOSBAY','LAZARO CARDENAS','PORTHUENEME','DONALDSONVILLE','PORTLAND, IN','SANFRANCISCO',
                    'CALETA COLOSO','BEARCREEK','BRUNSWICK, GA','ASTORIA','NEWORLEANS','LONGVIEW','MAZATLAN','BATONROUGE',
                    'CHARLESTON, SC','SAN NICOLAS','NEW WESTMINSTER','SAN ANTONIO','MORRO REDONDO','FERNDALE, WA','COLLEGEVILLE, MN',
                    'PLAQUEMINE','MEJILLONES','MEXICO /OTHER-PORT/','BENICIA','FREEPORT, TX','PRINCE RUPERT','ENSENADA','PORTANGELES',
                    'PANAMACITY','RICHMOND, CA','OLYMPIA','LAKECHARLES','GRAMERCY','GEISMAR','VALDEZ','PITTSBURG, CA',
                    'GUAM','SALVADOR','MAMONAL','WESTHAMPTONBEACH','ACAJUTLA','ECUADOR /OTHER-PORT/','PORTO ALEGRE','NANAIMO',
                    'NEDERLAND, TX','HOUSTON, PA','PORT MOODY','PUERTO QUETZAL','ALBANY','PUNTA LOBITOS','PHILADELPHIA',
                    'SANTOS','HUASCO','ELLISVILLE, MS','ROSARITO TERMINAL','COLON','IQUIQUE',
                    'ANGRA DOS REIS','COLUMBUS, MO','SANTO DOMINGO','GUAYMAS', 'SABINE','KINGSTON' ,'DUTCHHARBOR','SAIPAN']

    Africa_port = ['RICHARDS BAY','PORT LOUIS','EL SUWEIS' , 'PORT SAID','CAPE TOWN','KRIBI','SUEZ','PORT ELIZABETH',
                   'GAMBA','BONNY','EL ISKANDARIYA (ALEXANDRIA)','PORT TEWFIK','SALDANHA BAY','CAP LOPEZ','BRASS','EGYPT /OTHER-PORT/']

    
    if x in China_port :
        return "China"
    
    elif x in Asia_port :
        return "Asia"
    
    elif x in America_port :
        return "America"
    
    elif x in Africa_port :
        return "Africa"
    
    elif x in Europe_port :
        return "Europe"
    
    elif x in Oceania_port :
        return "Oceania"
    
    else :
        return "etc"

# %%
def Preprocessing_Ship() : 
    column = ['항명', '호출부호', '선명', '입항횟수', '입항횟수.1', '구분', '외내', '입출', '총톤수', '국제톤수',
       '징수톤수', '입항일시', '출항일시', 'CIO수속일자', '수리일시', '항해구분', 'MRN 번호', '국적',
       '국적.1', '계선장소', '계선장소.1', '계선장소.2', '차항지', '전출항지', '선박용도', '승무원1',
       '승무원2', '승객', '예선', '도선', '부선호출부호1', '부선호출부호2']
    
    df = pd.DataFrame(columns=column)
    
    ship_path_list = glob.glob( '../data/선박/*' )

    for file in ship_path_list : 

        filename = os.path.basename( file )
        print(filename)

        tmp_df = pd.read_excel(file, header=12)
        tmp_df.columns = column
        df = pd.concat([df,tmp_df])

    df.reset_index(inplace=True)
    df.drop(df.columns[0] , axis=1, inplace=True)
    
    df.drop( ['호출부호', '선명', '외내', '입출', '국제톤수', '징수톤수', 'CIO수속일자', '수리일시', '항해구분', 'MRN 번호', '국적.1', '계선장소', '계선장소.1', '계선장소.2', 
         '차항지', '부선호출부호1', '부선호출부호2' , '예선', '도선'], axis=1, inplace=True)
    
    
    df = df[ df['구분']=='최종' ]
    
    korea_ship = [ '기타항', '동해', '인천', '울산', '제주', '대산', '고현', '광양', '여천항', '완도',
       '옥계항', '군산', '여수', '부산', '포항', '옥포', '목포', '평택.당진', '온산', '당진',
       '묵호', '서귀포', '속초', '진해', '삼천포', '포항신항', '마산', '보령', '삼척', '대불',
       '감천', '장항', '영일만항', '하동화력', '호산항', '통영', '태안', '거문도', '장승포', '서울',
       '경인', '부산 신항', '남항', '목포 북항', '칼리오랑' ]
    
    
    mask = df['전출항지'].apply( lambda x : False if x in korea_ship else True )
    
    df = df[ mask ]
    
    df.drop([ '구분', '항명'], axis = 1, inplace=True)
    
    df.fillna(0, inplace=True)
    
    
    df.columns = [ 'Ship_year', 'Ship_count', 'Ship_Total_tonnage', 'Ship_arrival', 'Ship_departure', 'Ship_Nation', 'Ship_Prev_port', 
              'Ship_purpose', 'Ship_crew(korea)', 'Ship_crew(foreign)', 'Ship_passenger']
    
    df['Ship_Prev_port'] = df['Ship_Prev_port'].apply( lambda x : code( x ) )
    
    df.drop( [ 'Ship_departure', 'Ship_Nation', 'Ship_purpose'], axis=True, inplace=True)
    
    df['Ship_arrival'] = df['Ship_arrival'].apply( lambda x : x[:10])
    df['Ship_arrival'] = df['Ship_arrival'].apply( lambda x : int(x.replace('-', '')))
    df.rename(columns={"Ship_arrival":"Date"},inplace=True)
    
    china_df = df[ df['Ship_Prev_port'] == 'China' ]
    asia_df = df[ df['Ship_Prev_port'] == 'Asia' ]
    america_df = df[ df['Ship_Prev_port'] == 'America' ]
    africa_df = df[ df['Ship_Prev_port'] == 'Africa' ]
    europe_df = df[ df['Ship_Prev_port'] == 'Europe' ]
    oceania_df = df[ df['Ship_Prev_port'] == 'Oceania' ]
    
    china_group_df = china_df.groupby(china_df['Date']).sum()
    asia_group_df = asia_df.groupby(asia_df['Date']).sum()
    america_group_df = america_df.groupby(america_df['Date']).sum()
    africa_group_df = africa_df.groupby(africa_df['Date']).sum()
    europe_group_df = europe_df.groupby(europe_df['Date']).sum()
    oceania_group_df = oceania_df.groupby(europe_df['Date']).sum()
    
    china_group_df.to_csv('../data/Ship/China_group_df.csv')
    asia_group_df.to_csv('../data/Ship/Asia_group_df.csv')
    america_group_df.to_csv('../data/Ship/America_group_df.csv')
    africa_group_df.to_csv('../data/Ship/Africa_group_df.csv')
    europe_group_df.to_csv('../data/Ship/Europe_group_df.csv')
    oceania_group_df.to_csv('../data/Ship/Oceania_group_df.csv')

# %%
def Concat_All() :
    
    Preprocessing_Flight()
    Preprocessing_Ship()
    Preprocessing_Confirm()
    Preprocessing_News()
    
    China_Confirmer_group_df = pd.read_csv('../data/Confirmer/China_group_df.csv')
    Asia_Confirmer_group_df = pd.read_csv('../data/Confirmer/Asia_group_df.csv')
    Europe_Confirmer_group_df = pd.read_csv('../data/Confirmer/Europe_group_df.csv')
    America_Confirmer_group_df = pd.read_csv('../data/Confirmer/America_group_df.csv')
    Africa_Confirmer_group_df = pd.read_csv('../data/Confirmer/Africa_group_df.csv')
    Oceania_Confirmer_group_df = pd.read_csv('../data/Confirmer/Oceania_group_df.csv')
    
    China_Airport_group_df = pd.read_csv('../data/Airport/China_group_df.csv')
    Asia_Airport_group_df = pd.read_csv('../data/Airport/Asia_group_df.csv')
    Europe_Airport_group_df = pd.read_csv('../data/Airport/Europe_group_df.csv')
    America_Airport_group_df = pd.read_csv('../data/Airport/America_group_df.csv')
    Africa_Airport_group_df = pd.read_csv('../data/Airport/Africa_group_df.csv')
    Oceania_Airport_group_df = pd.read_csv('../data/Airport/Oceania_group_df.csv')
    
    China_Ship_group_df = pd.read_csv('../data/Ship/China_group_df.csv')
    Asia_Ship_group_df = pd.read_csv('../data/Ship/Asia_group_df.csv')
    Europe_Ship_group_df = pd.read_csv('../data/Ship/Europe_group_df.csv')
    America_Ship_group_df = pd.read_csv('../data/Ship/America_group_df.csv')
    Africa_Ship_group_df = pd.read_csv('../data/Ship/Africa_group_df.csv')
    Oceania_Ship_group_df = pd.read_csv('../data/Ship/Oceania_group_df.csv')

    China_News_group_df = pd.read_csv('../data/News/China_group_df.csv')
    Asia_News_group_df = pd.read_csv('../data/News/Asia_group_df.csv')
    Europe_News_group_df = pd.read_csv('../data/News/Europe_group_df.csv')
    America_News_group_df = pd.read_csv('../data/News/America_group_df.csv')
    Africa_News_group_df = pd.read_csv('../data/News/Africa_group_df.csv')
    Oceania_News_group_df = pd.read_csv('../data/News/Oceania_group_df.csv')
    
    China_Entry_group_df = pd.read_csv('../data/Entry/China_group_df.csv')
    Asia_Entry_group_df = pd.read_csv('../data/Entry/Asia_group_df.csv')
    Europe_Entry_group_df = pd.read_csv('../data/Entry/Europe_group_df.csv')
    America_Entry_group_df = pd.read_csv('../data/Entry/America_group_df.csv')
    Africa_Entry_group_df = pd.read_csv('../data/Entry/Africa_group_df.csv')
    Oceania_Entry_group_df = pd.read_csv('../data/Entry/Oceania_group_df.csv')
    
    China_Confirmer_group_df.set_index('Date', inplace=True)
    Asia_Confirmer_group_df.set_index('Date', inplace=True)
    Europe_Confirmer_group_df.set_index('Date', inplace=True)
    America_Confirmer_group_df.set_index('Date', inplace=True)
    Africa_Confirmer_group_df.set_index('Date', inplace=True)
    Oceania_Confirmer_group_df.set_index('Date', inplace=True)
    
    China_Airport_group_df.set_index('Date', inplace=True)
    Asia_Airport_group_df.set_index('Date', inplace=True)
    Europe_Airport_group_df.set_index('Date', inplace=True)
    America_Airport_group_df.set_index('Date', inplace=True)
    Africa_Airport_group_df.set_index('Date', inplace=True)
    Oceania_Airport_group_df.set_index('Date', inplace=True)
    
    China_Ship_group_df.set_index('Date', inplace=True)
    Asia_Ship_group_df.set_index('Date', inplace=True)
    Europe_Ship_group_df.set_index('Date', inplace=True)
    America_Ship_group_df.set_index('Date', inplace=True)
    Africa_Ship_group_df.set_index('Date', inplace=True)
    Oceania_Ship_group_df.set_index('Date', inplace=True)
    
    China_News_group_df.set_index('Date', inplace=True)
    Asia_News_group_df.set_index('Date', inplace=True)
    Europe_News_group_df.set_index('Date', inplace=True)
    America_News_group_df.set_index('Date', inplace=True)
    Africa_News_group_df.set_index('Date', inplace=True)
    Oceania_News_group_df.set_index('Date', inplace=True)
    
    China_Entry_group_df.set_index('Date', inplace=True)
    Asia_Entry_group_df.set_index('Date', inplace=True)
    Europe_Entry_group_df.set_index('Date', inplace=True)
    America_Entry_group_df.set_index('Date', inplace=True)
    Africa_Entry_group_df.set_index('Date', inplace=True)
    Oceania_Entry_group_df.set_index('Date', inplace=True)
    
    China_concat = pd.concat([China_Confirmer_group_df, China_Airport_group_df, China_Ship_group_df, China_News_group_df, China_Entry_group_df], axis=1)
    Asia_concat = pd.concat([Asia_Confirmer_group_df, Asia_Airport_group_df, Asia_Ship_group_df, Asia_News_group_df, Asia_Entry_group_df], axis=1)
    Europe_concat = pd.concat([Europe_Confirmer_group_df, Europe_Airport_group_df, Europe_Ship_group_df, Europe_News_group_df, Europe_Entry_group_df], axis=1)
    America_concat = pd.concat([America_Confirmer_group_df, America_Airport_group_df, America_Ship_group_df, America_News_group_df, America_Entry_group_df], axis=1)
    Africa_concat = pd.concat([Africa_Confirmer_group_df, Africa_Airport_group_df, Africa_Ship_group_df, Africa_News_group_df, Africa_Entry_group_df], axis=1)
    Oceania_concat = pd.concat([Oceania_Confirmer_group_df, Oceania_Airport_group_df, Oceania_Ship_group_df, Oceania_News_group_df, Oceania_Entry_group_df], axis=1)
    
    China_concat.fillna(0, inplace=True)
    Asia_concat.fillna(0, inplace=True)
    Europe_concat.fillna(0, inplace=True)
    America_concat.fillna(0, inplace=True)
    Africa_concat.fillna(0, inplace=True)
    Oceania_concat.fillna(0, inplace=True)

    China_concat.to_csv('../data/Concat/China_concat.csv')
    Asia_concat.to_csv('../data/Concat/Asia_concat.csv')
    Europe_concat.to_csv('../data/Concat/Europe_concat.csv')
    America_concat.to_csv('../data/Concat/America_concat.csv')
    Africa_concat.to_csv('../data/Concat/Africa_concat.csv')
    Oceania_concat.to_csv('../data/Concat/Oceania_concat.csv')

# %%
Concat_All()
# Out:
# 청주공항 국내항공사 수송현황 20191201.xlsx
# 청주공항 국내항공사 수송현황 20191202.xlsx
# 청주공항 국내항공사 수송현황 20191203.xlsx
# 청주공항 국내항공사 수송현황 20191204.xlsx
# 청주공항 국내항공사 수송현황 20191205.xlsx
# 청주공항 국내항공사 수송현황 20191206.xlsx
# 청주공항 국내항공사 수송현황 20191207.xlsx
# 청주공항 국내항공사 수송현황 20191208.xlsx
# 청주공항 국내항공사 수송현황 20191209.xlsx
# 청주공항 국내항공사 수송현황 20191210.xlsx
# 청주공항 국내항공사 수송현황 20191211.xlsx
# 청주공항 국내항공사 수송현황 20191212.xlsx
# 청주공항 국내항공사 수송현황 20191213.xlsx
# 청주공항 국내항공사 수송현황 20191214.xlsx
# 청주공항 국내항공사 수송현황 20191215.xlsx
# 청주공항 국내항공사 수송현황 20191216.xlsx
# 청주공항 국내항공사 수송현황 20191217.xlsx
# 청주공항 국내항공사 수송현황 20191218.xlsx
# 청주공항 국내항공사 수송현황 20191219.xlsx
# 청주공항 국내항공사 수송현황 20191220.xlsx
# 청주공항 국내항공사 수송현황 20191221.xlsx
# 청주공항 국내항공사 수송현황 20191222.xlsx
# 청주공항 국내항공사 수송현황 20191223.xlsx
# 청주공항 국내항공사 수송현황 20191224.xlsx
# 청주공항 국내항공사 수송현황 20191225.xlsx
# 청주공항 국내항공사 수송현황 20191226.xlsx
# 청주공항 국내항공사 수송현황 20191227.xlsx
# 청주공항 국내항공사 수송현황 20191228.xlsx
# 청주공항 국내항공사 수송현황 20191229.xlsx
# 청주공항 국내항공사 수송현황 20191230.xlsx
# 청주공항 국내항공사 수송현황 20191231.xlsx
# 청주공항 외국항공사 수송현황 20191201.xlsx
# 청주공항 외국항공사 수송현황 20191202.xlsx
# 청주공항 외국항공사 수송현황 20191203.xlsx
# 청주공항 외국항공사 수송현황 20191204.xlsx
# 청주공항 외국항공사 수송현황 20191205.xlsx
# 청주공항 외국항공사 수송현황 20191206.xlsx
# 청주공항 외국항공사 수송현황 20191207.xlsx
# 청주공항 외국항공사 수송현황 20191208.xlsx
# 청주공항 외국항공사 수송현황 20191209.xlsx
# 청주공항 외국항공사 수송현황 20191210.xlsx
# 청주공항 외국항공사 수송현황 20191211.xlsx
# 청주공항 외국항공사 수송현황 20191212.xlsx
# 청주공항 외국항공사 수송현황 20191213.xlsx
# 청주공항 외국항공사 수송현황 20191214.xlsx
# 청주공항 외국항공사 수송현황 20191215.xlsx
# 청주공항 외국항공사 수송현황 20191216.xlsx
# 청주공항 외국항공사 수송현황 20191217.xlsx
# 청주공항 외국항공사 수송현황 20191218.xlsx
# 청주공항 외국항공사 수송현황 20191219.xlsx
# 청주공항 외국항공사 수송현황 20191220.xlsx
# 청주공항 외국항공사 수송현황 20191221.xlsx
# 청주공항 외국항공사 수송현황 20191222.xlsx
# 청주공항 외국항공사 수송현황 20191223.xlsx
# 청주공항 외국항공사 수송현황 20191224.xlsx
# 청주공항 외국항공사 수송현황 20191225.xlsx
# 청주공항 외국항공사 수송현황 20191226.xlsx
# 청주공항 외국항공사 수송현황 20191227.xlsx
# 청주공항 외국항공사 수송현황 20191228.xlsx
# 청주공항 외국항공사 수송현황 20191229.xlsx
# 청주공항 외국항공사 수송현황 20191230.xlsx
# 청주공항 외국항공사 수송현황 20191231.xlsx
# 청주공항 국내항공사 수송현황 20200101.xlsx
# 청주공항 국내항공사 수송현황 20200102.xlsx
# 청주공항 국내항공사 수송현황 20200103.xlsx
# 청주공항 국내항공사 수송현황 20200104.xlsx
# 청주공항 국내항공사 수송현황 20200105.xlsx
# 청주공항 국내항공사 수송현황 20200106.xlsx
# 청주공항 국내항공사 수송현황 20200107.xlsx
# 청주공항 국내항공사 수송현황 20200108.xlsx
# 청주공항 국내항공사 수송현황 20200109.xlsx
# 청주공항 국내항공사 수송현황 20200110.xlsx
# 청주공항 국내항공사 수송현황 20200111.xlsx
# 청주공항 국내항공사 수송현황 20200112.xlsx
# 청주공항 국내항공사 수송현황 20200113.xlsx
# 청주공항 국내항공사 수송현황 20200114.xlsx
# 청주공항 국내항공사 수송현황 20200115.xlsx
# 청주공항 국내항공사 수송현황 20200116.xlsx
# 청주공항 국내항공사 수송현황 20200117.xlsx
# 청주공항 국내항공사 수송현황 20200118.xlsx
# 청주공항 국내항공사 수송현황 20200119.xlsx
# 청주공항 국내항공사 수송현황 20200120.xlsx
# 청주공항 국내항공사 수송현황 20200121.xlsx
# 청주공항 국내항공사 수송현황 20200122.xlsx
# 청주공항 국내항공사 수송현황 20200123.xlsx
# 청주공항 국내항공사 수송현황 20200124.xlsx
# 청주공항 국내항공사 수송현황 20200125.xlsx
# 청주공항 국내항공사 수송현황 20200126.xlsx
# 청주공항 국내항공사 수송현황 20200127.xlsx
# 청주공항 국내항공사 수송현황 20200128.xlsx
# 청주공항 국내항공사 수송현황 20200129.xlsx
# 청주공항 국내항공사 수송현황 20200130.xlsx
# 청주공항 국내항공사 수송현황 20200131.xlsx
# 청주공항 외국항공사 수송현황 20200101.xlsx
# 청주공항 외국항공사 수송현황 20200102.xlsx
# 청주공항 외국항공사 수송현황 20200103.xlsx
# 청주공항 외국항공사 수송현황 20200104.xlsx
# 청주공항 외국항공사 수송현황 20200105.xlsx
# 청주공항 외국항공사 수송현황 20200106.xlsx
# 청주공항 외국항공사 수송현황 20200107.xlsx
# 청주공항 외국항공사 수송현황 20200108.xlsx
# 청주공항 외국항공사 수송현황 20200109.xlsx
# 청주공항 외국항공사 수송현황 20200110.xlsx
# 청주공항 외국항공사 수송현황 20200111.xlsx
# 청주공항 외국항공사 수송현황 20200112.xlsx
# 청주공항 외국항공사 수송현황 20200113.xlsx
# 청주공항 외국항공사 수송현황 20200114.xlsx
# 청주공항 외국항공사 수송현황 20200115.xlsx
# 청주공항 외국항공사 수송현황 20200116.xlsx
# 청주공항 외국항공사 수송현황 20200117.xlsx
# 청주공항 외국항공사 수송현황 20200118.xlsx
# 청주공항 외국항공사 수송현황 20200119.xlsx
# 청주공항 외국항공사 수송현황 20200120.xlsx
# 청주공항 외국항공사 수송현황 20200121.xlsx
# 청주공항 외국항공사 수송현황 20200122.xlsx
# 청주공항 외국항공사 수송현황 20200123.xlsx
# 청주공항 외국항공사 수송현황 20200124.xlsx
# 청주공항 외국항공사 수송현황 20200125.xlsx
# 청주공항 외국항공사 수송현황 20200126.xlsx
# 청주공항 외국항공사 수송현황 20200127.xlsx
# 청주공항 외국항공사 수송현황 20200128.xlsx
# 청주공항 외국항공사 수송현황 20200129.xlsx
# 청주공항 외국항공사 수송현황 20200130.xlsx
# 청주공항 외국항공사 수송현황 20200131.xlsx
# 청주공항 국내항공사 수송현황 20200201.xlsx
# 청주공항 국내항공사 수송현황 20200202.xlsx
# 청주공항 국내항공사 수송현황 20200203.xlsx
# 청주공항 국내항공사 수송현황 20200204.xlsx
# 청주공항 국내항공사 수송현황 20200205.xlsx
# 청주공항 국내항공사 수송현황 20200206.xlsx
# 청주공항 국내항공사 수송현황 20200207.xlsx
# 청주공항 국내항공사 수송현황 20200208.xlsx
# 청주공항 국내항공사 수송현황 20200209.xlsx
# 청주공항 국내항공사 수송현황 20200210.xlsx
# 청주공항 국내항공사 수송현황 20200211.xlsx
# 청주공항 국내항공사 수송현황 20200212.xlsx
# 청주공항 국내항공사 수송현황 20200213.xlsx
# 청주공항 국내항공사 수송현황 20200214.xlsx
# 청주공항 국내항공사 수송현황 20200215.xlsx
# 청주공항 국내항공사 수송현황 20200216.xlsx
# 청주공항 국내항공사 수송현황 20200217.xlsx
# 청주공항 국내항공사 수송현황 20200218.xlsx
# 청주공항 국내항공사 수송현황 20200219.xlsx
# 청주공항 국내항공사 수송현황 20200220.xlsx
# 청주공항 국내항공사 수송현황 20200221.xlsx
# 청주공항 국내항공사 수송현황 20200222.xlsx
# 청주공항 국내항공사 수송현황 20200223.xlsx
# 청주공항 국내항공사 수송현황 20200224.xlsx
# 청주공항 국내항공사 수송현황 20200225.xlsx
# 청주공항 국내항공사 수송현황 20200226.xlsx
# 청주공항 국내항공사 수송현황 20200227.xlsx
# 청주공항 국내항공사 수송현황 20200228.xlsx
# 청주공항 국내항공사 수송현황 20200229.xlsx
# 청주공항 외국항공사 수송현황 20200201.xlsx
# 청주공항 외국항공사 수송현황 20200202.xlsx
# 청주공항 외국항공사 수송현황 20200203.xlsx
# 청주공항 외국항공사 수송현황 20200204.xlsx
# 청주공항 외국항공사 수송현황 20200205.xlsx
# 청주공항 외국항공사 수송현황 20200206.xlsx
# 청주공항 외국항공사 수송현황 20200207.xlsx
# 청주공항 외국항공사 수송현황 20200208.xlsx
# 청주공항 외국항공사 수송현황 20200209.xlsx
# 청주공항 외국항공사 수송현황 20200210.xlsx
# 청주공항 외국항공사 수송현황 20200211.xlsx
# 청주공항 외국항공사 수송현황 20200212.xlsx
# 청주공항 외국항공사 수송현황 20200213.xlsx
# 청주공항 외국항공사 수송현황 20200214.xlsx
# 청주공항 외국항공사 수송현황 20200215.xlsx
# 청주공항 외국항공사 수송현황 20200216.xlsx
# 청주공항 외국항공사 수송현황 20200217.xlsx
# 청주공항 외국항공사 수송현황 20200218.xlsx
# 청주공항 외국항공사 수송현황 20200219.xlsx
# 청주공항 외국항공사 수송현황 20200220.xlsx
# 청주공항 외국항공사 수송현황 20200221.xlsx
# 청주공항 외국항공사 수송현황 20200222.xlsx
# 청주공항 외국항공사 수송현황 20200223.xlsx
# 청주공항 외국항공사 수송현황 20200224.xlsx
# 청주공항 외국항공사 수송현황 20200225.xlsx
# 청주공항 외국항공사 수송현황 20200226.xlsx
# 청주공항 외국항공사 수송현황 20200227.xlsx
# 청주공항 외국항공사 수송현황 20200228.xlsx
# 청주공항 외국항공사 수송현황 20200229.xlsx
# 청주공항 국내항공사 수송현황 20200301.xlsx
# 청주공항 국내항공사 수송현황 20200302.xlsx
# 청주공항 국내항공사 수송현황 20200303.xlsx
# 청주공항 국내항공사 수송현황 20200304.xlsx
# 청주공항 국내항공사 수송현황 20200305.xlsx
# 청주공항 국내항공사 수송현황 20200306.xlsx
# 청주공항 국내항공사 수송현황 20200307.xlsx
# 청주공항 국내항공사 수송현황 20200308.xlsx
# 청주공항 국내항공사 수송현황 20200309.xlsx
# 청주공항 국내항공사 수송현황 20200310.xlsx
# 청주공항 국내항공사 수송현황 20200311.xlsx
# 청주공항 국내항공사 수송현황 20200312.xlsx
# 청주공항 국내항공사 수송현황 20200313.xlsx
# 청주공항 국내항공사 수송현황 20200314.xlsx
# 청주공항 국내항공사 수송현황 20200315.xlsx
# 청주공항 국내항공사 수송현황 20200316.xlsx
# 청주공항 국내항공사 수송현황 20200317.xlsx
# 청주공항 국내항공사 수송현황 20200318.xlsx
# 청주공항 국내항공사 수송현황 20200319.xlsx
# 청주공항 국내항공사 수송현황 20200320.xlsx
# 청주공항 국내항공사 수송현황 20200321.xlsx
# 청주공항 국내항공사 수송현황 20200322.xlsx
# 청주공항 국내항공사 수송현황 20200323.xlsx
# 청주공항 국내항공사 수송현황 20200324.xlsx
# 청주공항 국내항공사 수송현황 20200325.xlsx
# 청주공항 국내항공사 수송현황 20200326.xlsx
# 청주공항 국내항공사 수송현황 20200327.xlsx
# 청주공항 국내항공사 수송현황 20200328.xlsx
# 청주공항 국내항공사 수송현황 20200329.xlsx
# 청주공항 국내항공사 수송현황 20200330.xlsx
# 청주공항 국내항공사 수송현황 20200331.xlsx
# 청주공항 외국항공사 수송현황 20200301.xlsx
# 청주공항 외국항공사 수송현황 20200302.xlsx
# 청주공항 외국항공사 수송현황 20200303.xlsx
# 청주공항 외국항공사 수송현황 20200304.xlsx
# 청주공항 외국항공사 수송현황 20200305.xlsx
# 청주공항 외국항공사 수송현황 20200306.xlsx
# 청주공항 외국항공사 수송현황 20200307.xlsx
# 청주공항 외국항공사 수송현황 20200308.xlsx
# 청주공항 외국항공사 수송현황 20200309.xlsx
# 청주공항 외국항공사 수송현황 20200310.xlsx
# 청주공항 외국항공사 수송현황 20200311.xlsx
# 청주공항 외국항공사 수송현황 20200312.xlsx
# 청주공항 외국항공사 수송현황 20200313.xlsx
# 청주공항 외국항공사 수송현황 20200314.xlsx
# 청주공항 외국항공사 수송현황 20200315.xlsx
# 청주공항 외국항공사 수송현황 20200316.xlsx
# 청주공항 외국항공사 수송현황 20200317.xlsx
# 청주공항 외국항공사 수송현황 20200318.xlsx
# 청주공항 외국항공사 수송현황 20200319.xlsx
# 청주공항 외국항공사 수송현황 20200320.xlsx
# 청주공항 외국항공사 수송현황 20200321.xlsx
# 청주공항 외국항공사 수송현황 20200322.xlsx
# 청주공항 외국항공사 수송현황 20200323.xlsx
# 청주공항 외국항공사 수송현황 20200324.xlsx
# 청주공항 외국항공사 수송현황 20200325.xlsx
# 청주공항 외국항공사 수송현황 20200326.xlsx
# 청주공항 외국항공사 수송현황 20200327.xlsx
# 청주공항 외국항공사 수송현황 20200328.xlsx
# 청주공항 외국항공사 수송현황 20200329.xlsx
# 청주공항 외국항공사 수송현황 20200330.xlsx
# 청주공항 외국항공사 수송현황 20200331.xlsx
# 청주공항 국내항공사 수송현황 20200401.xlsx
# 청주공항 국내항공사 수송현황 2020040129.xlsx
# 청주공항 국내항공사 수송현황 2020040130.xlsx
# 청주공항 국내항공사 수송현황 20200402.xlsx
# 청주공항 국내항공사 수송현황 20200403.xlsx
# 청주공항 국내항공사 수송현황 20200404.xlsx
# 청주공항 국내항공사 수송현황 20200405.xlsx
# 청주공항 국내항공사 수송현황 20200406.xlsx
# 청주공항 국내항공사 수송현황 20200407.xlsx
# 청주공항 국내항공사 수송현황 20200408.xlsx
# 청주공항 국내항공사 수송현황 20200409.xlsx
# 청주공항 국내항공사 수송현황 20200410.xlsx
# 청주공항 국내항공사 수송현황 20200411.xlsx
# 청주공항 국내항공사 수송현황 20200412.xlsx
# 청주공항 국내항공사 수송현황 20200413.xlsx
# 청주공항 국내항공사 수송현황 20200414.xlsx
# 청주공항 국내항공사 수송현황 20200415.xlsx
# 청주공항 국내항공사 수송현황 20200416.xlsx
# 청주공항 국내항공사 수송현황 20200417.xlsx
# 청주공항 국내항공사 수송현황 20200418.xlsx
# 청주공항 국내항공사 수송현황 20200419.xlsx
# 청주공항 국내항공사 수송현황 20200420.xlsx
# 청주공항 국내항공사 수송현황 20200421.xlsx
# 청주공항 국내항공사 수송현황 20200422.xlsx
# 청주공항 국내항공사 수송현황 20200423.xlsx
# 청주공항 국내항공사 수송현황 20200424.xlsx
# 청주공항 국내항공사 수송현황 20200425.xlsx
# 청주공항 국내항공사 수송현황 20200426.xlsx
# 청주공항 국내항공사 수송현황 20200427.xlsx
# 청주공항 국내항공사 수송현황 20200428.xlsx
# 청주공항 외국항공사 수송현황 20200401.xlsx
# 청주공항 외국항공사 수송현황 20200402.xlsx
# 청주공항 외국항공사 수송현황 20200403.xlsx
# 청주공항 외국항공사 수송현황 20200404.xlsx
# 청주공항 외국항공사 수송현황 20200405.xlsx
# 청주공항 외국항공사 수송현황 20200406.xlsx
# 청주공항 외국항공사 수송현황 20200407.xlsx
# 청주공항 외국항공사 수송현황 20200408.xlsx
# 청주공항 외국항공사 수송현황 20200409.xlsx
# 청주공항 외국항공사 수송현황 20200410.xlsx
# 청주공항 외국항공사 수송현황 20200411.xlsx
# 청주공항 외국항공사 수송현황 20200412.xlsx
# 청주공항 외국항공사 수송현황 20200413.xlsx
# 청주공항 외국항공사 수송현황 20200414.xlsx
# 청주공항 외국항공사 수송현황 20200415.xlsx
# 청주공항 외국항공사 수송현황 20200416.xlsx
# 청주공항 외국항공사 수송현황 20200417.xlsx
# 청주공항 외국항공사 수송현황 20200418.xlsx
# 청주공항 외국항공사 수송현황 20200419.xlsx
# 청주공항 외국항공사 수송현황 20200420.xlsx
# 청주공항 외국항공사 수송현황 20200421.xlsx
# 청주공항 외국항공사 수송현황 20200422.xlsx
# 청주공항 외국항공사 수송현황 20200423.xlsx
# 청주공항 외국항공사 수송현황 20200424.xlsx
# 청주공항 외국항공사 수송현황 20200425.xlsx
# 청주공항 외국항공사 수송현황 20200426.xlsx
# 청주공항 외국항공사 수송현황 20200427.xlsx
# 청주공항 외국항공사 수송현황 20200428.xlsx
# 청주공항 외국항공사 수송현황 20200429.xlsx
# 청주공항 외국항공사 수송현황 20200430.xlsx
# 청주공항 국내항공사 수송현황 20200501.xlsx
# 청주공항 국내항공사 수송현황 20200502.xlsx
# 청주공항 국내항공사 수송현황 20200503.xlsx
# 청주공항 국내항공사 수송현황 20200504.xlsx
# 청주공항 국내항공사 수송현황 20200505.xlsx
# 청주공항 외국항공사 수송현황 20200501.xlsx
# 청주공항 외국항공사 수송현황 20200502.xlsx
# 청주공항 외국항공사 수송현황 20200503.xlsx
# 청주공항 외국항공사 수송현황 20200504.xlsx
# 청주공항 외국항공사 수송현황 20200505.xlsx
# 대구공항 국내항공사 수송현황 20191201.xlsx
# 대구공항 국내항공사 수송현황 20191202.xlsx
# 대구공항 국내항공사 수송현황 20191203.xlsx
# 대구공항 국내항공사 수송현황 20191204.xlsx
# 대구공항 국내항공사 수송현황 20191205.xlsx
# 대구공항 국내항공사 수송현황 20191206.xlsx
# 대구공항 국내항공사 수송현황 20191207.xlsx
# 대구공항 국내항공사 수송현황 20191208.xlsx
# 대구공항 국내항공사 수송현황 20191209.xlsx
# 대구공항 국내항공사 수송현황 20191210.xlsx
# 대구공항 국내항공사 수송현황 20191211.xlsx
# 대구공항 국내항공사 수송현황 20191212.xlsx
# 대구공항 국내항공사 수송현황 20191213.xlsx
# 대구공항 국내항공사 수송현황 20191214.xlsx
# 대구공항 국내항공사 수송현황 20191215.xlsx
# 대구공항 국내항공사 수송현황 20191216.xlsx
# 대구공항 국내항공사 수송현황 20191217.xlsx
# 대구공항 국내항공사 수송현황 20191218.xlsx
# 대구공항 국내항공사 수송현황 20191219.xlsx
# 대구공항 국내항공사 수송현황 20191220.xlsx
# 대구공항 국내항공사 수송현황 20191221.xlsx
# 대구공항 국내항공사 수송현황 20191222.xlsx
# 대구공항 국내항공사 수송현황 20191223.xlsx
# 대구공항 국내항공사 수송현황 20191224.xlsx
# 대구공항 국내항공사 수송현황 20191225.xlsx
# 대구공항 국내항공사 수송현황 20191226.xlsx
# 대구공항 국내항공사 수송현황 20191227.xlsx
# 대구공항 국내항공사 수송현황 20191228.xlsx
# 대구공항 국내항공사 수송현황 20191229.xlsx
# 대구공항 국내항공사 수송현황 20191230.xlsx
# 대구공항 국내항공사 수송현황 20191231.xlsx
# 대구공항 외국항공사 수송현황 20191201.xlsx
# 대구공항 외국항공사 수송현황 20191202.xlsx
# 대구공항 외국항공사 수송현황 20191203.xlsx
# 대구공항 외국항공사 수송현황 20191204.xlsx
# 대구공항 외국항공사 수송현황 20191205.xlsx
# 대구공항 외국항공사 수송현황 20191206.xlsx
# 대구공항 외국항공사 수송현황 20191207.xlsx
# 대구공항 외국항공사 수송현황 20191208.xlsx
# 대구공항 외국항공사 수송현황 20191209.xlsx
# 대구공항 외국항공사 수송현황 20191210.xlsx
# 대구공항 외국항공사 수송현황 20191211.xlsx
# 대구공항 외국항공사 수송현황 20191212.xlsx
# 대구공항 외국항공사 수송현황 20191213.xlsx
# 대구공항 외국항공사 수송현황 20191214.xlsx
# 대구공항 외국항공사 수송현황 20191215.xlsx
# 대구공항 외국항공사 수송현황 20191216.xlsx
# 대구공항 외국항공사 수송현황 20191217.xlsx
# 대구공항 외국항공사 수송현황 20191218.xlsx
# 대구공항 외국항공사 수송현황 20191219.xlsx
# 대구공항 외국항공사 수송현황 20191220.xlsx
# 대구공항 외국항공사 수송현황 20191221.xlsx
# 대구공항 외국항공사 수송현황 20191222.xlsx
# 대구공항 외국항공사 수송현황 20191223.xlsx
# 대구공항 외국항공사 수송현황 20191224.xlsx
# 대구공항 외국항공사 수송현황 20191225.xlsx
# 대구공항 외국항공사 수송현황 20191226.xlsx
# 대구공항 외국항공사 수송현황 20191227.xlsx
# 대구공항 외국항공사 수송현황 20191228.xlsx
# 대구공항 외국항공사 수송현황 20191229.xlsx
# 대구공항 외국항공사 수송현황 20191230.xlsx
# 대구공항 외국항공사 수송현황 20191231.xlsx
# 대구공항 국내항공사 수송현황 20200101.xlsx
# 대구공항 국내항공사 수송현황 20200102.xlsx
# 대구공항 국내항공사 수송현황 20200103.xlsx
# 대구공항 국내항공사 수송현황 20200104.xlsx
# 대구공항 국내항공사 수송현황 20200105.xlsx
# 대구공항 국내항공사 수송현황 20200106.xlsx
# 대구공항 국내항공사 수송현황 20200107.xlsx
# 대구공항 국내항공사 수송현황 20200108.xlsx
# 대구공항 국내항공사 수송현황 20200109.xlsx
# 대구공항 국내항공사 수송현황 20200110.xlsx
# 대구공항 국내항공사 수송현황 20200111.xlsx
# 대구공항 국내항공사 수송현황 20200112.xlsx
# 대구공항 국내항공사 수송현황 20200113.xlsx
# 대구공항 국내항공사 수송현황 20200114.xlsx
# 대구공항 국내항공사 수송현황 20200115.xlsx
# 대구공항 국내항공사 수송현황 20200116.xlsx
# 대구공항 국내항공사 수송현황 20200117.xlsx
# 대구공항 국내항공사 수송현황 20200118.xlsx
# 대구공항 국내항공사 수송현황 20200119.xlsx
# 대구공항 국내항공사 수송현황 20200120.xlsx
# 대구공항 국내항공사 수송현황 20200121.xlsx
# 대구공항 국내항공사 수송현황 20200122.xlsx
# 대구공항 국내항공사 수송현황 20200123.xlsx
# 대구공항 국내항공사 수송현황 20200124.xlsx
# 대구공항 국내항공사 수송현황 20200125.xlsx
# 대구공항 국내항공사 수송현황 20200126.xlsx
# 대구공항 국내항공사 수송현황 20200127.xlsx
# 대구공항 국내항공사 수송현황 20200128.xlsx
# 대구공항 국내항공사 수송현황 20200129.xlsx
# 대구공항 국내항공사 수송현황 20200130.xlsx
# 대구공항 국내항공사 수송현황 20200131.xlsx
# 대구공항 외국항공사 수송현황 20200101.xlsx
# 대구공항 외국항공사 수송현황 20200102.xlsx
# 대구공항 외국항공사 수송현황 20200103.xlsx
# 대구공항 외국항공사 수송현황 20200104.xlsx
# 대구공항 외국항공사 수송현황 20200105.xlsx
# 대구공항 외국항공사 수송현황 20200106.xlsx
# 대구공항 외국항공사 수송현황 20200107.xlsx
# 대구공항 외국항공사 수송현황 20200108.xlsx
# 대구공항 외국항공사 수송현황 20200109.xlsx
# 대구공항 외국항공사 수송현황 20200110.xlsx
# 대구공항 외국항공사 수송현황 20200111.xlsx
# 대구공항 외국항공사 수송현황 20200112.xlsx
# 대구공항 외국항공사 수송현황 20200113.xlsx
# 대구공항 외국항공사 수송현황 20200114.xlsx
# 대구공항 외국항공사 수송현황 20200115.xlsx
# 대구공항 외국항공사 수송현황 20200116.xlsx
# 대구공항 외국항공사 수송현황 20200117.xlsx
# 대구공항 외국항공사 수송현황 20200118.xlsx
# 대구공항 외국항공사 수송현황 20200119.xlsx
# 대구공항 외국항공사 수송현황 20200120.xlsx
# 대구공항 외국항공사 수송현황 20200121.xlsx
# 대구공항 외국항공사 수송현황 20200122.xlsx
# 대구공항 외국항공사 수송현황 20200123.xlsx
# 대구공항 외국항공사 수송현황 20200124.xlsx
# 대구공항 외국항공사 수송현황 20200125.xlsx
# 대구공항 외국항공사 수송현황 20200126.xlsx
# 대구공항 외국항공사 수송현황 20200127.xlsx
# 대구공항 외국항공사 수송현황 20200128.xlsx
# 대구공항 외국항공사 수송현황 20200129.xlsx
# 대구공항 외국항공사 수송현황 20200130.xlsx
# 대구공항 외국항공사 수송현황 20200131.xlsx
# 대구공항 국내항공사 수송현황 20200201.xlsx
# 대구공항 국내항공사 수송현황 20200202.xlsx
# 대구공항 국내항공사 수송현황 20200203.xlsx
# 대구공항 국내항공사 수송현황 20200204.xlsx
# 대구공항 국내항공사 수송현황 20200205.xlsx
# 대구공항 국내항공사 수송현황 20200206.xlsx
# 대구공항 국내항공사 수송현황 20200207.xlsx
# 대구공항 국내항공사 수송현황 20200208.xlsx
# 대구공항 국내항공사 수송현황 20200209.xlsx
# 대구공항 국내항공사 수송현황 20200210.xlsx
# 대구공항 국내항공사 수송현황 20200211.xlsx
# 대구공항 국내항공사 수송현황 20200212.xlsx
# 대구공항 국내항공사 수송현황 20200213.xlsx
# 대구공항 국내항공사 수송현황 20200214.xlsx
# 대구공항 국내항공사 수송현황 20200215.xlsx
# 대구공항 국내항공사 수송현황 20200216.xlsx
# 대구공항 국내항공사 수송현황 20200217.xlsx
# 대구공항 국내항공사 수송현황 20200218.xlsx
# 대구공항 국내항공사 수송현황 20200219.xlsx
# 대구공항 국내항공사 수송현황 20200220.xlsx
# 대구공항 국내항공사 수송현황 20200221.xlsx
# 대구공항 국내항공사 수송현황 20200222.xlsx
# 대구공항 국내항공사 수송현황 20200223.xlsx
# 대구공항 국내항공사 수송현황 20200224.xlsx
# 대구공항 국내항공사 수송현황 20200225.xlsx
# 대구공항 국내항공사 수송현황 20200226.xlsx
# 대구공항 국내항공사 수송현황 20200227.xlsx
# 대구공항 국내항공사 수송현황 20200228.xlsx
# 대구공항 국내항공사 수송현황 20200229.xlsx
# 대구공항 외국항공사 수송현황 20200201.xlsx
# 대구공항 외국항공사 수송현황 20200202.xlsx
# 대구공항 외국항공사 수송현황 20200203.xlsx
# 대구공항 외국항공사 수송현황 20200204.xlsx
# 대구공항 외국항공사 수송현황 20200205.xlsx
# 대구공항 외국항공사 수송현황 20200206.xlsx
# 대구공항 외국항공사 수송현황 20200207.xlsx
# 대구공항 외국항공사 수송현황 20200208.xlsx
# 대구공항 외국항공사 수송현황 20200209.xlsx
# 대구공항 외국항공사 수송현황 20200210.xlsx
# 대구공항 외국항공사 수송현황 20200211.xlsx
# 대구공항 외국항공사 수송현황 20200212.xlsx
# 대구공항 외국항공사 수송현황 20200213.xlsx
# 대구공항 외국항공사 수송현황 20200214.xlsx
# 대구공항 외국항공사 수송현황 20200215.xlsx
# 대구공항 외국항공사 수송현황 20200216.xlsx
# 대구공항 외국항공사 수송현황 20200217.xlsx
# 대구공항 외국항공사 수송현황 20200218.xlsx
# 대구공항 외국항공사 수송현황 20200219.xlsx
# 대구공항 외국항공사 수송현황 20200220.xlsx
# 대구공항 외국항공사 수송현황 20200221.xlsx
# 대구공항 외국항공사 수송현황 20200222.xlsx
# 대구공항 외국항공사 수송현황 20200223.xlsx
# 대구공항 외국항공사 수송현황 20200224.xlsx
# 대구공항 외국항공사 수송현황 20200225.xlsx
# 대구공항 외국항공사 수송현황 20200226.xlsx
# 대구공항 외국항공사 수송현황 20200227.xlsx
# 대구공항 외국항공사 수송현황 20200228.xlsx
# 대구공항 외국항공사 수송현황 20200229.xlsx
# 대구공항 국내항공사 수송현황 20200301.xlsx
# 대구공항 국내항공사 수송현황 20200302.xlsx
# 대구공항 국내항공사 수송현황 20200303.xlsx
# 대구공항 국내항공사 수송현황 20200304.xlsx
# 대구공항 국내항공사 수송현황 20200305.xlsx
# 대구공항 국내항공사 수송현황 20200306.xlsx
# 대구공항 국내항공사 수송현황 20200307.xlsx
# 대구공항 국내항공사 수송현황 20200308.xlsx
# 대구공항 국내항공사 수송현황 20200309.xlsx
# 대구공항 국내항공사 수송현황 20200310.xlsx
# 대구공항 국내항공사 수송현황 20200311.xlsx
# 대구공항 국내항공사 수송현황 20200312.xlsx
# 대구공항 국내항공사 수송현황 20200313.xlsx
# 대구공항 국내항공사 수송현황 20200314.xlsx
# 대구공항 국내항공사 수송현황 20200315.xlsx
# 대구공항 국내항공사 수송현황 20200316.xlsx
# 대구공항 국내항공사 수송현황 20200317.xlsx
# 대구공항 국내항공사 수송현황 20200318.xlsx
# 대구공항 국내항공사 수송현황 20200319.xlsx
# 대구공항 국내항공사 수송현황 20200320.xlsx
# 대구공항 국내항공사 수송현황 20200321.xlsx
# 대구공항 국내항공사 수송현황 20200322.xlsx
# 대구공항 국내항공사 수송현황 20200323.xlsx
# 대구공항 국내항공사 수송현황 20200324.xlsx
# 대구공항 국내항공사 수송현황 20200325.xlsx
# 대구공항 국내항공사 수송현황 20200326.xlsx
# 대구공항 국내항공사 수송현황 20200327.xlsx
# 대구공항 국내항공사 수송현황 20200328.xlsx
# 대구공항 국내항공사 수송현황 20200329.xlsx
# 대구공항 국내항공사 수송현황 20200330.xlsx
# 대구공항 국내항공사 수송현황 20200331.xlsx
# 대구공항 외국항공사 수송현황 20200301.xlsx
# 대구공항 외국항공사 수송현황 20200302.xlsx
# 대구공항 외국항공사 수송현황 20200303.xlsx
# 대구공항 외국항공사 수송현황 20200304.xlsx
# 대구공항 외국항공사 수송현황 20200305.xlsx
# 대구공항 외국항공사 수송현황 20200306.xlsx
# 대구공항 외국항공사 수송현황 20200307.xlsx
# 대구공항 외국항공사 수송현황 20200308.xlsx
# 대구공항 외국항공사 수송현황 20200309.xlsx
# 대구공항 외국항공사 수송현황 20200310.xlsx
# 대구공항 외국항공사 수송현황 20200311.xlsx
# 대구공항 외국항공사 수송현황 20200312.xlsx
# 대구공항 외국항공사 수송현황 20200313.xlsx
# 대구공항 외국항공사 수송현황 20200314.xlsx
# 대구공항 외국항공사 수송현황 20200315.xlsx
# 대구공항 외국항공사 수송현황 20200316.xlsx
# 대구공항 외국항공사 수송현황 20200317.xlsx
# 대구공항 외국항공사 수송현황 20200318.xlsx
# 대구공항 외국항공사 수송현황 20200319.xlsx
# 대구공항 외국항공사 수송현황 20200320.xlsx
# 대구공항 외국항공사 수송현황 20200321.xlsx
# 대구공항 외국항공사 수송현황 20200322.xlsx
# 대구공항 외국항공사 수송현황 20200323.xlsx
# 대구공항 외국항공사 수송현황 20200324.xlsx
# 대구공항 외국항공사 수송현황 20200325.xlsx
# 대구공항 외국항공사 수송현황 20200326.xlsx
# 대구공항 외국항공사 수송현황 20200327.xlsx
# 대구공항 외국항공사 수송현황 20200328.xlsx
# 대구공항 외국항공사 수송현황 20200329.xlsx
# 대구공항 외국항공사 수송현황 20200330.xlsx
# 대구공항 외국항공사 수송현황 20200331.xlsx
# 대구공항 국내항공사 수송현황 20200401.xlsx
# 대구공항 국내항공사 수송현황 20200402.xlsx
# 대구공항 국내항공사 수송현황 20200403.xlsx
# 대구공항 국내항공사 수송현황 20200404.xlsx
# 대구공항 국내항공사 수송현황 20200405.xlsx
# 대구공항 국내항공사 수송현황 20200406.xlsx
# 대구공항 국내항공사 수송현황 20200407.xlsx
# 대구공항 국내항공사 수송현황 20200408.xlsx
# 대구공항 국내항공사 수송현황 20200409.xlsx
# 대구공항 국내항공사 수송현황 20200410.xlsx
# 대구공항 국내항공사 수송현황 20200411.xlsx
# 대구공항 국내항공사 수송현황 20200412.xlsx
# 대구공항 국내항공사 수송현황 20200413.xlsx
# 대구공항 국내항공사 수송현황 20200414.xlsx
# 대구공항 국내항공사 수송현황 20200415.xlsx
# 대구공항 국내항공사 수송현황 20200416.xlsx
# 대구공항 국내항공사 수송현황 20200417.xlsx
# 대구공항 국내항공사 수송현황 20200418.xlsx
# 대구공항 국내항공사 수송현황 20200419.xlsx
# 대구공항 국내항공사 수송현황 20200420.xlsx
# 대구공항 국내항공사 수송현황 20200421.xlsx
# 대구공항 국내항공사 수송현황 20200422.xlsx
# 대구공항 국내항공사 수송현황 20200423.xlsx
# 대구공항 국내항공사 수송현황 20200424.xlsx
# 대구공항 국내항공사 수송현황 20200425.xlsx
# 대구공항 국내항공사 수송현황 20200426.xlsx
# 대구공항 국내항공사 수송현황 20200427.xlsx
# 대구공항 국내항공사 수송현황 20200428.xlsx
# 대구공항 국내항공사 수송현황 20200429.xlsx
# 대구공항 국내항공사 수송현황 20200430.xlsx
# 대구공항 외국항공사 수송현황 20200401.xlsx
# 대구공항 외국항공사 수송현황 20200402.xlsx
# 대구공항 외국항공사 수송현황 20200403.xlsx
# 대구공항 외국항공사 수송현황 20200404.xlsx
# 대구공항 외국항공사 수송현황 20200405.xlsx
# 대구공항 외국항공사 수송현황 20200406.xlsx
# 대구공항 외국항공사 수송현황 20200407.xlsx
# 대구공항 외국항공사 수송현황 20200408.xlsx
# 대구공항 외국항공사 수송현황 20200409.xlsx
# 대구공항 외국항공사 수송현황 20200410.xlsx
# 대구공항 외국항공사 수송현황 20200411.xlsx
# 대구공항 외국항공사 수송현황 20200412.xlsx
# 대구공항 외국항공사 수송현황 20200413.xlsx
# 대구공항 외국항공사 수송현황 20200414.xlsx
# 대구공항 외국항공사 수송현황 20200415.xlsx
# 대구공항 외국항공사 수송현황 20200416.xlsx
# 대구공항 외국항공사 수송현황 20200417.xlsx
# 대구공항 외국항공사 수송현황 20200418.xlsx
# 대구공항 외국항공사 수송현황 20200419.xlsx
# 대구공항 외국항공사 수송현황 20200420.xlsx
# 대구공항 외국항공사 수송현황 20200421.xlsx
# 대구공항 외국항공사 수송현황 20200422.xlsx
# 대구공항 외국항공사 수송현황 20200423.xlsx
# 대구공항 외국항공사 수송현황 20200424.xlsx
# 대구공항 외국항공사 수송현황 20200425.xlsx
# 대구공항 외국항공사 수송현황 20200426.xlsx
# 대구공항 외국항공사 수송현황 20200427.xlsx
# 대구공항 외국항공사 수송현황 20200428.xlsx
# 대구공항 외국항공사 수송현황 20200429.xlsx
# 대구공항 외국항공사 수송현황 20200430.xlsx
# 대구공항 국내항공사 수송현황 20200501.xlsx
# 대구공항 국내항공사 수송현황 20200502.xlsx
# 대구공항 국내항공사 수송현황 20200503.xlsx
# 대구공항 국내항공사 수송현황 20200504.xlsx
# 대구공항 국내항공사 수송현황 20200505.xlsx
# 대구공항 외국항공사 수송현황 20200501.xlsx
# 대구공항 외국항공사 수송현황 20200502.xlsx
# 대구공항 외국항공사 수송현황 20200503.xlsx
# 대구공항 외국항공사 수송현황 20200504.xlsx
# 대구공항 외국항공사 수송현황 20200505.xlsx
# 김해공항 국내항공사 수송현황 20191201.xlsx
# 김해공항 국내항공사 수송현황 20191202.xlsx
# 김해공항 국내항공사 수송현황 20191203.xlsx
# 김해공항 국내항공사 수송현황 20191204.xlsx
# 김해공항 국내항공사 수송현황 20191205.xlsx
# 김해공항 국내항공사 수송현황 20191206.xlsx
# 김해공항 국내항공사 수송현황 20191207.xlsx
# 김해공항 국내항공사 수송현황 20191208.xlsx
# 김해공항 국내항공사 수송현황 20191209.xlsx
# 김해공항 국내항공사 수송현황 20191210.xlsx
# 김해공항 국내항공사 수송현황 20191211.xlsx
# 김해공항 국내항공사 수송현황 20191212.xlsx
# 김해공항 국내항공사 수송현황 20191213.xlsx
# 김해공항 국내항공사 수송현황 20191214.xlsx
# 김해공항 국내항공사 수송현황 20191215.xlsx
# 김해공항 국내항공사 수송현황 20191216.xlsx
# 김해공항 국내항공사 수송현황 20191217.xlsx
# 김해공항 국내항공사 수송현황 20191218.xlsx
# 김해공항 국내항공사 수송현황 20191219.xlsx
# 김해공항 국내항공사 수송현황 20191220.xlsx
# 김해공항 국내항공사 수송현황 20191221.xlsx
# 김해공항 국내항공사 수송현황 20191222.xlsx
# 김해공항 국내항공사 수송현황 20191223.xlsx
# 김해공항 국내항공사 수송현황 20191224.xlsx
# 김해공항 국내항공사 수송현황 20191225.xlsx
# 김해공항 국내항공사 수송현황 20191226.xlsx
# 김해공항 국내항공사 수송현황 20191227.xlsx
# 김해공항 국내항공사 수송현황 20191228.xlsx
# 김해공항 국내항공사 수송현황 20191229.xlsx
# 김해공항 국내항공사 수송현황 20191230.xlsx
# 김해공항 국내항공사 수송현황 20191231.xlsx
# 김해공항 외국항공사 수송현황 20191201.xlsx
# 김해공항 외국항공사 수송현황 20191202.xlsx
# 김해공항 외국항공사 수송현황 20191203.xlsx
# 김해공항 외국항공사 수송현황 20191204.xlsx
# 김해공항 외국항공사 수송현황 20191205.xlsx
# 김해공항 외국항공사 수송현황 20191206.xlsx
# 김해공항 외국항공사 수송현황 20191207.xlsx
# 김해공항 외국항공사 수송현황 20191208.xlsx
# 김해공항 외국항공사 수송현황 20191209.xlsx
# 김해공항 외국항공사 수송현황 20191210.xlsx
# 김해공항 외국항공사 수송현황 20191211.xlsx
# 김해공항 외국항공사 수송현황 20191212.xlsx
# 김해공항 외국항공사 수송현황 20191213.xlsx
# 김해공항 외국항공사 수송현황 20191214.xlsx
# 김해공항 외국항공사 수송현황 20191215.xlsx
# 김해공항 외국항공사 수송현황 20191216.xlsx
# 김해공항 외국항공사 수송현황 20191217.xlsx
# 김해공항 외국항공사 수송현황 20191218.xlsx
# 김해공항 외국항공사 수송현황 20191219.xlsx
# 김해공항 외국항공사 수송현황 20191220.xlsx
# 김해공항 외국항공사 수송현황 20191221.xlsx
# 김해공항 외국항공사 수송현황 20191222.xlsx
# 김해공항 외국항공사 수송현황 20191223.xlsx
# 김해공항 외국항공사 수송현황 20191224.xlsx
# 김해공항 외국항공사 수송현황 20191225.xlsx
# 김해공항 외국항공사 수송현황 20191226.xlsx
# 김해공항 외국항공사 수송현황 20191227.xlsx
# 김해공항 외국항공사 수송현황 20191228.xlsx
# 김해공항 외국항공사 수송현황 20191229.xlsx
# 김해공항 외국항공사 수송현황 20191230.xlsx
# 김해공항 외국항공사 수송현황 20191231.xlsx
# 김해공항 국내항공사 수송현황 20200101.xlsx
# 김해공항 국내항공사 수송현황 20200102.xlsx
# 김해공항 국내항공사 수송현황 20200103.xlsx
# 김해공항 국내항공사 수송현황 20200104.xlsx
# 김해공항 국내항공사 수송현황 20200105.xlsx
# 김해공항 국내항공사 수송현황 20200106.xlsx
# 김해공항 국내항공사 수송현황 20200107.xlsx
# 김해공항 국내항공사 수송현황 20200108.xlsx
# 김해공항 국내항공사 수송현황 20200109.xlsx
# 김해공항 국내항공사 수송현황 20200110.xlsx
# 김해공항 국내항공사 수송현황 20200111.xlsx
# 김해공항 국내항공사 수송현황 20200112.xlsx
# 김해공항 국내항공사 수송현황 20200113.xlsx
# 김해공항 국내항공사 수송현황 20200114.xlsx
# 김해공항 국내항공사 수송현황 20200115.xlsx
# 김해공항 국내항공사 수송현황 20200116.xlsx
# 김해공항 국내항공사 수송현황 20200117.xlsx
# 김해공항 국내항공사 수송현황 20200118.xlsx
# 김해공항 국내항공사 수송현황 20200119.xlsx
# 김해공항 국내항공사 수송현황 20200120.xlsx
# 김해공항 국내항공사 수송현황 20200121.xlsx
# 김해공항 국내항공사 수송현황 20200122.xlsx
# 김해공항 국내항공사 수송현황 20200123.xlsx
# 김해공항 국내항공사 수송현황 20200124.xlsx
# 김해공항 국내항공사 수송현황 20200125.xlsx
# 김해공항 국내항공사 수송현황 20200126.xlsx
# 김해공항 국내항공사 수송현황 20200127.xlsx
# 김해공항 국내항공사 수송현황 20200128.xlsx
# 김해공항 국내항공사 수송현황 20200129.xlsx
# 김해공항 국내항공사 수송현황 20200130.xlsx
# 김해공항 국내항공사 수송현황 20200131.xlsx
# 김해공항 외국항공사 수송현황 20200101.xlsx
# 김해공항 외국항공사 수송현황 20200102.xlsx
# 김해공항 외국항공사 수송현황 20200103.xlsx
# 김해공항 외국항공사 수송현황 20200104.xlsx
# 김해공항 외국항공사 수송현황 20200105.xlsx
# 김해공항 외국항공사 수송현황 20200106.xlsx
# 김해공항 외국항공사 수송현황 20200107.xlsx
# 김해공항 외국항공사 수송현황 20200108.xlsx
# 김해공항 외국항공사 수송현황 20200109.xlsx
# 김해공항 외국항공사 수송현황 20200110.xlsx
# 김해공항 외국항공사 수송현황 20200111.xlsx
# 김해공항 외국항공사 수송현황 20200112.xlsx
# 김해공항 외국항공사 수송현황 20200113.xlsx
# 김해공항 외국항공사 수송현황 20200114.xlsx
# 김해공항 외국항공사 수송현황 20200115.xlsx
# 김해공항 외국항공사 수송현황 20200116.xlsx
# 김해공항 외국항공사 수송현황 20200117.xlsx
# 김해공항 외국항공사 수송현황 20200118.xlsx
# 김해공항 외국항공사 수송현황 20200119.xlsx
# 김해공항 외국항공사 수송현황 20200120.xlsx
# 김해공항 외국항공사 수송현황 20200121.xlsx
# 김해공항 외국항공사 수송현황 20200122.xlsx
# 김해공항 외국항공사 수송현황 20200123.xlsx
# 김해공항 외국항공사 수송현황 20200124.xlsx
# 김해공항 외국항공사 수송현황 20200125.xlsx
# 김해공항 외국항공사 수송현황 20200126.xlsx
# 김해공항 외국항공사 수송현황 20200127.xlsx
# 김해공항 외국항공사 수송현황 20200128.xlsx
# 김해공항 외국항공사 수송현황 20200129.xlsx
# 김해공항 외국항공사 수송현황 20200130.xlsx
# 김해공항 외국항공사 수송현황 20200131.xlsx
# 김해공항 국내항공사 수송현황 20200201.xlsx
# 김해공항 국내항공사 수송현황 20200202.xlsx
# 김해공항 국내항공사 수송현황 20200203.xlsx
# 김해공항 국내항공사 수송현황 20200204.xlsx
# 김해공항 국내항공사 수송현황 20200205.xlsx
# 김해공항 국내항공사 수송현황 20200206.xlsx
# 김해공항 국내항공사 수송현황 20200207.xlsx
# 김해공항 국내항공사 수송현황 20200208.xlsx
# 김해공항 국내항공사 수송현황 20200209.xlsx
# 김해공항 국내항공사 수송현황 20200210.xlsx
# 김해공항 국내항공사 수송현황 20200211.xlsx
# 김해공항 국내항공사 수송현황 20200212.xlsx
# 김해공항 국내항공사 수송현황 20200213.xlsx
# 김해공항 국내항공사 수송현황 20200214.xlsx
# 김해공항 국내항공사 수송현황 20200215.xlsx
# 김해공항 국내항공사 수송현황 20200216.xlsx
# 김해공항 국내항공사 수송현황 20200217.xlsx
# 김해공항 국내항공사 수송현황 20200218.xlsx
# 김해공항 국내항공사 수송현황 20200219.xlsx
# 김해공항 국내항공사 수송현황 20200220.xlsx
# 김해공항 국내항공사 수송현황 20200221.xlsx
# 김해공항 국내항공사 수송현황 20200222.xlsx
# 김해공항 국내항공사 수송현황 20200223.xlsx
# 김해공항 국내항공사 수송현황 20200224.xlsx
# 김해공항 국내항공사 수송현황 20200225.xlsx
# 김해공항 국내항공사 수송현황 20200226.xlsx
# 김해공항 국내항공사 수송현황 20200227.xlsx
# 김해공항 국내항공사 수송현황 20200228.xlsx
# 김해공항 국내항공사 수송현황 20200229.xlsx
# 김해공항 외국항공사 수송현황 20200201.xlsx
# 김해공항 외국항공사 수송현황 20200202.xlsx
# 김해공항 외국항공사 수송현황 20200203.xlsx
# 김해공항 외국항공사 수송현황 20200204.xlsx
# 김해공항 외국항공사 수송현황 20200205.xlsx
# 김해공항 외국항공사 수송현황 20200206.xlsx
# 김해공항 외국항공사 수송현황 20200207.xlsx
# 김해공항 외국항공사 수송현황 20200208.xlsx
# 김해공항 외국항공사 수송현황 20200209.xlsx
# 김해공항 외국항공사 수송현황 20200210.xlsx
# 김해공항 외국항공사 수송현황 20200211.xlsx
# 김해공항 외국항공사 수송현황 20200212.xlsx
# 김해공항 외국항공사 수송현황 20200213.xlsx
# 김해공항 외국항공사 수송현황 20200214.xlsx
# 김해공항 외국항공사 수송현황 20200215.xlsx
# 김해공항 외국항공사 수송현황 20200216.xlsx
# 김해공항 외국항공사 수송현황 20200217.xlsx
# 김해공항 외국항공사 수송현황 20200218.xlsx
# 김해공항 외국항공사 수송현황 20200219.xlsx
# 김해공항 외국항공사 수송현황 20200220.xlsx
# 김해공항 외국항공사 수송현황 20200221.xlsx
# 김해공항 외국항공사 수송현황 20200222.xlsx
# 김해공항 외국항공사 수송현황 20200223.xlsx
# 김해공항 외국항공사 수송현황 20200224.xlsx
# 김해공항 외국항공사 수송현황 20200225.xlsx
# 김해공항 외국항공사 수송현황 20200226.xlsx
# 김해공항 외국항공사 수송현황 20200227.xlsx
# 김해공항 외국항공사 수송현황 20200228.xlsx
# 김해공항 외국항공사 수송현황 20200229.xlsx
# 김해공항 국내항공사 수송현황 20200301.xlsx
# 김해공항 국내항공사 수송현황 20200302.xlsx
# 김해공항 국내항공사 수송현황 20200303.xlsx
# 김해공항 국내항공사 수송현황 20200304.xlsx
# 김해공항 국내항공사 수송현황 20200305.xlsx
# 김해공항 국내항공사 수송현황 20200306.xlsx
# 김해공항 국내항공사 수송현황 20200307.xlsx
# 김해공항 국내항공사 수송현황 20200308.xlsx
# 김해공항 국내항공사 수송현황 20200309.xlsx
# 김해공항 국내항공사 수송현황 20200310.xlsx
# 김해공항 국내항공사 수송현황 20200311.xlsx
# 김해공항 국내항공사 수송현황 20200312.xlsx
# 김해공항 국내항공사 수송현황 20200313.xlsx
# 김해공항 국내항공사 수송현황 20200314.xlsx
# 김해공항 국내항공사 수송현황 20200315.xlsx
# 김해공항 국내항공사 수송현황 20200316.xlsx
# 김해공항 국내항공사 수송현황 20200317.xlsx
# 김해공항 국내항공사 수송현황 20200318.xlsx
# 김해공항 국내항공사 수송현황 20200319.xlsx
# 김해공항 국내항공사 수송현황 20200320.xlsx
# 김해공항 국내항공사 수송현황 20200321.xlsx
# 김해공항 국내항공사 수송현황 20200322.xlsx
# 김해공항 국내항공사 수송현황 20200323.xlsx
# 김해공항 국내항공사 수송현황 20200324.xlsx
# 김해공항 국내항공사 수송현황 20200325.xlsx
# 김해공항 국내항공사 수송현황 20200326.xlsx
# 김해공항 국내항공사 수송현황 20200327.xlsx
# 김해공항 국내항공사 수송현황 20200328.xlsx
# 김해공항 국내항공사 수송현황 20200329.xlsx
# 김해공항 국내항공사 수송현황 20200330.xlsx
# 김해공항 국내항공사 수송현황 20200331.xlsx
# 김해공항 외국항공사 수송현황 20200301.xlsx
# 김해공항 외국항공사 수송현황 20200302.xlsx
# 김해공항 외국항공사 수송현황 20200303.xlsx
# 김해공항 외국항공사 수송현황 20200304.xlsx
# 김해공항 외국항공사 수송현황 20200305.xlsx
# 김해공항 외국항공사 수송현황 20200306.xlsx
# 김해공항 외국항공사 수송현황 20200307.xlsx
# 김해공항 외국항공사 수송현황 20200308.xlsx
# 김해공항 외국항공사 수송현황 20200309.xlsx
# 김해공항 외국항공사 수송현황 20200310.xlsx
# 김해공항 외국항공사 수송현황 20200311.xlsx
# 김해공항 외국항공사 수송현황 20200312.xlsx
# 김해공항 외국항공사 수송현황 20200313.xlsx
# 김해공항 외국항공사 수송현황 20200314.xlsx
# 김해공항 외국항공사 수송현황 20200315.xlsx
# 김해공항 외국항공사 수송현황 20200316.xlsx
# 김해공항 외국항공사 수송현황 20200317.xlsx
# 김해공항 외국항공사 수송현황 20200318.xlsx
# 김해공항 외국항공사 수송현황 20200319.xlsx
# 김해공항 외국항공사 수송현황 20200320.xlsx
# 김해공항 외국항공사 수송현황 20200321.xlsx
# 김해공항 외국항공사 수송현황 20200322.xlsx
# 김해공항 외국항공사 수송현황 20200323.xlsx
# 김해공항 외국항공사 수송현황 20200324.xlsx
# 김해공항 외국항공사 수송현황 20200325.xlsx
# 김해공항 외국항공사 수송현황 20200326.xlsx
# 김해공항 외국항공사 수송현황 20200327.xlsx
# 김해공항 외국항공사 수송현황 20200328.xlsx
# 김해공항 외국항공사 수송현황 20200329.xlsx
# 김해공항 외국항공사 수송현황 20200330.xlsx
# 김해공항 외국항공사 수송현황 20200331.xlsx
# 김해공항 국내항공사 수송현황 20200401.xlsx
# 김해공항 국내항공사 수송현황 20200402.xlsx
# 김해공항 국내항공사 수송현황 20200403.xlsx
# 김해공항 국내항공사 수송현황 20200404.xlsx
# 김해공항 국내항공사 수송현황 20200405.xlsx
# 김해공항 국내항공사 수송현황 20200406.xlsx
# 김해공항 국내항공사 수송현황 20200407.xlsx
# 김해공항 국내항공사 수송현황 20200408.xlsx
# 김해공항 국내항공사 수송현황 20200409.xlsx
# 김해공항 국내항공사 수송현황 20200410.xlsx
# 김해공항 국내항공사 수송현황 20200411.xlsx
# 김해공항 국내항공사 수송현황 20200412.xlsx
# 김해공항 국내항공사 수송현황 20200413.xlsx
# 김해공항 국내항공사 수송현황 20200414.xlsx
# 김해공항 국내항공사 수송현황 20200415.xlsx
# 김해공항 국내항공사 수송현황 20200416.xlsx
# 김해공항 국내항공사 수송현황 20200417.xlsx
# 김해공항 국내항공사 수송현황 20200418.xlsx
# 김해공항 국내항공사 수송현황 20200419.xlsx
# 김해공항 국내항공사 수송현황 20200420.xlsx
# 김해공항 국내항공사 수송현황 20200421.xlsx
# 김해공항 국내항공사 수송현황 20200422.xlsx
# 김해공항 국내항공사 수송현황 20200423.xlsx
# 김해공항 국내항공사 수송현황 20200424.xlsx
# 김해공항 국내항공사 수송현황 20200425.xlsx
# 김해공항 국내항공사 수송현황 20200426.xlsx
# 김해공항 국내항공사 수송현황 20200427.xlsx
# 김해공항 국내항공사 수송현황 20200428.xlsx
# 김해공항 국내항공사 수송현황 20200429.xlsx
# 김해공항 국내항공사 수송현황 20200430.xlsx
# 김해공항 외국항공사 수송현황 20200401.xlsx
# 김해공항 외국항공사 수송현황 20200402.xlsx
# 김해공항 외국항공사 수송현황 20200403.xlsx
# 김해공항 외국항공사 수송현황 20200404.xlsx
# 김해공항 외국항공사 수송현황 20200405.xlsx
# 김해공항 외국항공사 수송현황 20200406.xlsx
# 김해공항 외국항공사 수송현황 20200407.xlsx
# 김해공항 외국항공사 수송현황 20200408.xlsx
# 김해공항 외국항공사 수송현황 20200409.xlsx
# 김해공항 외국항공사 수송현황 20200410.xlsx
# 김해공항 외국항공사 수송현황 20200411.xlsx
# 김해공항 외국항공사 수송현황 20200412.xlsx
# 김해공항 외국항공사 수송현황 20200413.xlsx
# 김해공항 외국항공사 수송현황 20200414.xlsx
# 김해공항 외국항공사 수송현황 20200415.xlsx
# 김해공항 외국항공사 수송현황 20200416.xlsx
# 김해공항 외국항공사 수송현황 20200417.xlsx
# 김해공항 외국항공사 수송현황 20200418.xlsx
# 김해공항 외국항공사 수송현황 20200419.xlsx
# 김해공항 외국항공사 수송현황 20200420.xlsx
# 김해공항 외국항공사 수송현황 20200421.xlsx
# 김해공항 외국항공사 수송현황 20200422.xlsx
# 김해공항 외국항공사 수송현황 20200423.xlsx
# 김해공항 외국항공사 수송현황 20200424.xlsx
# 김해공항 외국항공사 수송현황 20200425.xlsx
# 김해공항 외국항공사 수송현황 20200426.xlsx
# 김해공항 외국항공사 수송현황 20200427.xlsx
# 김해공항 외국항공사 수송현황 20200428.xlsx
# 김해공항 외국항공사 수송현황 20200429.xlsx
# 김해공항 외국항공사 수송현황 20200430.xlsx
# 김해공항 국내항공사 수송현황 20200501.xlsx
# 김해공항 국내항공사 수송현황 20200502.xlsx
# 김해공항 국내항공사 수송현황 20200503.xlsx
# 김해공항 국내항공사 수송현황 20200504.xlsx
# 김해공항 국내항공사 수송현황 20200505.xlsx
# 김해공항 외국항공사 수송현황 20200501.xlsx
# 김해공항 외국항공사 수송현황 20200502.xlsx
# 김해공항 외국항공사 수송현황 20200503.xlsx
# 김해공항 외국항공사 수송현황 20200504.xlsx
# 김해공항 외국항공사 수송현황 20200505.xlsx
# 김포공항 국내항공사 수송현황 20191201.xlsx
# 김포공항 국내항공사 수송현황 20191202.xlsx
# 김포공항 국내항공사 수송현황 20191203.xlsx
# 김포공항 국내항공사 수송현황 20191204.xlsx
# 김포공항 국내항공사 수송현황 20191205.xlsx
# 김포공항 국내항공사 수송현황 20191206.xlsx
# 김포공항 국내항공사 수송현황 20191207.xlsx
# 김포공항 국내항공사 수송현황 20191208.xlsx
# 김포공항 국내항공사 수송현황 20191209.xlsx
# 김포공항 국내항공사 수송현황 20191210.xlsx
# 김포공항 국내항공사 수송현황 20191211.xlsx
# 김포공항 국내항공사 수송현황 20191212.xlsx
# 김포공항 국내항공사 수송현황 20191213.xlsx
# 김포공항 국내항공사 수송현황 20191214.xlsx
# 김포공항 국내항공사 수송현황 20191215.xlsx
# 김포공항 국내항공사 수송현황 20191216.xlsx
# 김포공항 국내항공사 수송현황 20191217.xlsx
# 김포공항 국내항공사 수송현황 20191218.xlsx
# 김포공항 국내항공사 수송현황 20191219.xlsx
# 김포공항 국내항공사 수송현황 20191220.xlsx
# 김포공항 국내항공사 수송현황 20191221.xlsx
# 김포공항 국내항공사 수송현황 20191222.xlsx
# 김포공항 국내항공사 수송현황 20191223.xlsx
# 김포공항 국내항공사 수송현황 20191224.xlsx
# 김포공항 국내항공사 수송현황 20191225.xlsx
# 김포공항 국내항공사 수송현황 20191226.xlsx
# 김포공항 국내항공사 수송현황 20191227.xlsx
# 김포공항 국내항공사 수송현황 20191228.xlsx
# 김포공항 국내항공사 수송현황 20191229.xlsx
# 김포공항 국내항공사 수송현황 20191230.xlsx
# 김포공항 국내항공사 수송현황 20191231.xlsx
# 김포공항 외국항공사 수송현황 20191201.xlsx
# 김포공항 외국항공사 수송현황 20191202.xlsx
# 김포공항 외국항공사 수송현황 20191203.xlsx
# 김포공항 외국항공사 수송현황 20191204.xlsx
# 김포공항 외국항공사 수송현황 20191205.xlsx
# 김포공항 외국항공사 수송현황 20191206.xlsx
# 김포공항 외국항공사 수송현황 20191207.xlsx
# 김포공항 외국항공사 수송현황 20191208.xlsx
# 김포공항 외국항공사 수송현황 20191209.xlsx
# 김포공항 외국항공사 수송현황 20191210.xlsx
# 김포공항 외국항공사 수송현황 20191211.xlsx
# 김포공항 외국항공사 수송현황 20191212.xlsx
# 김포공항 외국항공사 수송현황 20191213.xlsx
# 김포공항 외국항공사 수송현황 20191214.xlsx
# 김포공항 외국항공사 수송현황 20191215.xlsx
# 김포공항 외국항공사 수송현황 20191216.xlsx
# 김포공항 외국항공사 수송현황 20191217.xlsx
# 김포공항 외국항공사 수송현황 20191218.xlsx
# 김포공항 외국항공사 수송현황 20191219.xlsx
# 김포공항 외국항공사 수송현황 20191220.xlsx
# 김포공항 외국항공사 수송현황 20191221.xlsx
# 김포공항 외국항공사 수송현황 20191222.xlsx
# 김포공항 외국항공사 수송현황 20191223.xlsx
# 김포공항 외국항공사 수송현황 20191224.xlsx
# 김포공항 외국항공사 수송현황 20191225.xlsx
# 김포공항 외국항공사 수송현황 20191226.xlsx
# 김포공항 외국항공사 수송현황 20191227.xlsx
# 김포공항 외국항공사 수송현황 20191228.xlsx
# 김포공항 외국항공사 수송현황 20191229.xlsx
# 김포공항 외국항공사 수송현황 20191230.xlsx
# 김포공항 외국항공사 수송현황 20191231.xlsx
# 김포공항 국내항공사 수송현황 20200101.xlsx
# 김포공항 국내항공사 수송현황 20200102.xlsx
# 김포공항 국내항공사 수송현황 20200103.xlsx
# 김포공항 국내항공사 수송현황 20200104.xlsx
# 김포공항 국내항공사 수송현황 20200105.xlsx
# 김포공항 국내항공사 수송현황 20200106.xlsx
# 김포공항 국내항공사 수송현황 20200107.xlsx
# 김포공항 국내항공사 수송현황 20200108.xlsx
# 김포공항 국내항공사 수송현황 20200109.xlsx
# 김포공항 국내항공사 수송현황 20200110.xlsx
# 김포공항 국내항공사 수송현황 20200111.xlsx
# 김포공항 국내항공사 수송현황 20200112.xlsx
# 김포공항 국내항공사 수송현황 20200113.xlsx
# 김포공항 국내항공사 수송현황 20200114.xlsx
# 김포공항 국내항공사 수송현황 20200115.xlsx
# 김포공항 국내항공사 수송현황 20200116.xlsx
# 김포공항 국내항공사 수송현황 20200117.xlsx
# 김포공항 국내항공사 수송현황 20200118.xlsx
# 김포공항 국내항공사 수송현황 20200119.xlsx
# 김포공항 국내항공사 수송현황 20200120.xlsx
# 김포공항 국내항공사 수송현황 20200121.xlsx
# 김포공항 국내항공사 수송현황 20200122.xlsx
# 김포공항 국내항공사 수송현황 20200123.xlsx
# 김포공항 국내항공사 수송현황 20200124.xlsx
# 김포공항 국내항공사 수송현황 20200125.xlsx
# 김포공항 국내항공사 수송현황 20200126.xlsx
# 김포공항 국내항공사 수송현황 20200127.xlsx
# 김포공항 국내항공사 수송현황 20200128.xlsx
# 김포공항 국내항공사 수송현황 20200129.xlsx
# 김포공항 국내항공사 수송현황 20200130.xlsx
# 김포공항 국내항공사 수송현황 20200131.xlsx
# 김포공항 외국항공사 수송현황 20200101.xlsx
# 김포공항 외국항공사 수송현황 20200102.xlsx
# 김포공항 외국항공사 수송현황 20200103.xlsx
# 김포공항 외국항공사 수송현황 20200104.xlsx
# 김포공항 외국항공사 수송현황 20200105.xlsx
# 김포공항 외국항공사 수송현황 20200106.xlsx
# 김포공항 외국항공사 수송현황 20200107.xlsx
# 김포공항 외국항공사 수송현황 20200108.xlsx
# 김포공항 외국항공사 수송현황 20200109.xlsx
# 김포공항 외국항공사 수송현황 20200110.xlsx
# 김포공항 외국항공사 수송현황 20200111.xlsx
# 김포공항 외국항공사 수송현황 20200112.xlsx
# 김포공항 외국항공사 수송현황 20200113.xlsx
# 김포공항 외국항공사 수송현황 20200114.xlsx
# 김포공항 외국항공사 수송현황 20200115.xlsx
# 김포공항 외국항공사 수송현황 20200116.xlsx
# 김포공항 외국항공사 수송현황 20200117.xlsx
# 김포공항 외국항공사 수송현황 20200118.xlsx
# 김포공항 외국항공사 수송현황 20200119.xlsx
# 김포공항 외국항공사 수송현황 20200120.xlsx
# 김포공항 외국항공사 수송현황 20200121.xlsx
# 김포공항 외국항공사 수송현황 20200122.xlsx
# 김포공항 외국항공사 수송현황 20200123.xlsx
# 김포공항 외국항공사 수송현황 20200124.xlsx
# 김포공항 외국항공사 수송현황 20200125.xlsx
# 김포공항 외국항공사 수송현황 20200126.xlsx
# 김포공항 외국항공사 수송현황 20200127.xlsx
# 김포공항 외국항공사 수송현황 20200128.xlsx
# 김포공항 외국항공사 수송현황 20200129.xlsx
# 김포공항 외국항공사 수송현황 20200130.xlsx
# 김포공항 외국항공사 수송현황 20200131.xlsx
# 김포공항 국내항공사 수송현황 20200201.xlsx
# 김포공항 국내항공사 수송현황 20200202.xlsx
# 김포공항 국내항공사 수송현황 20200203.xlsx
# 김포공항 국내항공사 수송현황 20200204.xlsx
# 김포공항 국내항공사 수송현황 20200205.xlsx
# 김포공항 국내항공사 수송현황 20200206.xlsx
# 김포공항 국내항공사 수송현황 20200207.xlsx
# 김포공항 국내항공사 수송현황 20200208.xlsx
# 김포공항 국내항공사 수송현황 20200209.xlsx
# 김포공항 국내항공사 수송현황 20200210.xlsx
# 김포공항 국내항공사 수송현황 20200211.xlsx
# 김포공항 국내항공사 수송현황 20200212.xlsx
# 김포공항 국내항공사 수송현황 20200213.xlsx
# 김포공항 국내항공사 수송현황 20200214.xlsx
# 김포공항 국내항공사 수송현황 20200215.xlsx
# 김포공항 국내항공사 수송현황 20200216.xlsx
# 김포공항 국내항공사 수송현황 20200217.xlsx
# 김포공항 국내항공사 수송현황 20200218.xlsx
# 김포공항 국내항공사 수송현황 20200219.xlsx
# 김포공항 국내항공사 수송현황 20200220.xlsx
# 김포공항 국내항공사 수송현황 20200221.xlsx
# 김포공항 국내항공사 수송현황 20200222.xlsx
# 김포공항 국내항공사 수송현황 20200223.xlsx
# 김포공항 국내항공사 수송현황 20200224.xlsx
# 김포공항 국내항공사 수송현황 20200225.xlsx
# 김포공항 국내항공사 수송현황 20200226.xlsx
# 김포공항 국내항공사 수송현황 20200227.xlsx
# 김포공항 국내항공사 수송현황 20200228.xlsx
# 김포공항 국내항공사 수송현황 20200229.xlsx
# 김포공항 외국항공사 수송현황 20200201.xlsx
# 김포공항 외국항공사 수송현황 20200202.xlsx
# 김포공항 외국항공사 수송현황 20200203.xlsx
# 김포공항 외국항공사 수송현황 20200204.xlsx
# 김포공항 외국항공사 수송현황 20200205.xlsx
# 김포공항 외국항공사 수송현황 20200206.xlsx
# 김포공항 외국항공사 수송현황 20200207.xlsx
# 김포공항 외국항공사 수송현황 20200208.xlsx
# 김포공항 외국항공사 수송현황 20200209.xlsx
# 김포공항 외국항공사 수송현황 20200210.xlsx
# 김포공항 외국항공사 수송현황 20200211.xlsx
# 김포공항 외국항공사 수송현황 20200212.xlsx
# 김포공항 외국항공사 수송현황 20200213.xlsx
# 김포공항 외국항공사 수송현황 20200214.xlsx
# 김포공항 외국항공사 수송현황 20200215.xlsx
# 김포공항 외국항공사 수송현황 20200216.xlsx
# 김포공항 외국항공사 수송현황 20200217.xlsx
# 김포공항 외국항공사 수송현황 20200218.xlsx
# 김포공항 외국항공사 수송현황 20200219.xlsx
# 김포공항 외국항공사 수송현황 20200220.xlsx
# 김포공항 외국항공사 수송현황 20200221.xlsx
# 김포공항 외국항공사 수송현황 20200222.xlsx
# 김포공항 외국항공사 수송현황 20200223.xlsx
# 김포공항 외국항공사 수송현황 20200224.xlsx
# 김포공항 외국항공사 수송현황 20200225.xlsx
# 김포공항 외국항공사 수송현황 20200226.xlsx
# 김포공항 외국항공사 수송현황 20200227.xlsx
# 김포공항 외국항공사 수송현황 20200228.xlsx
# 김포공항 외국항공사 수송현황 20200229.xlsx
# 김포공항 국내항공사 수송현황 20200301.xlsx
# 김포공항 국내항공사 수송현황 20200302.xlsx
# 김포공항 국내항공사 수송현황 20200303.xlsx
# 김포공항 국내항공사 수송현황 20200304.xlsx
# 김포공항 국내항공사 수송현황 20200305.xlsx
# 김포공항 국내항공사 수송현황 20200306.xlsx
# 김포공항 국내항공사 수송현황 20200307.xlsx
# 김포공항 국내항공사 수송현황 20200308.xlsx
# 김포공항 국내항공사 수송현황 20200309.xlsx
# 김포공항 국내항공사 수송현황 20200310.xlsx
# 김포공항 국내항공사 수송현황 20200311.xlsx
# 김포공항 국내항공사 수송현황 20200312.xlsx
# 김포공항 국내항공사 수송현황 20200313.xlsx
# 김포공항 국내항공사 수송현황 20200314.xlsx
# 김포공항 국내항공사 수송현황 20200315.xlsx
# 김포공항 국내항공사 수송현황 20200316.xlsx
# 김포공항 국내항공사 수송현황 20200317.xlsx
# 김포공항 국내항공사 수송현황 20200318.xlsx
# 김포공항 국내항공사 수송현황 20200319.xlsx
# 김포공항 국내항공사 수송현황 20200320.xlsx
# 김포공항 국내항공사 수송현황 20200321.xlsx
# 김포공항 국내항공사 수송현황 20200322.xlsx
# 김포공항 국내항공사 수송현황 20200323.xlsx
# 김포공항 국내항공사 수송현황 20200324.xlsx
# 김포공항 국내항공사 수송현황 20200325.xlsx
# 김포공항 국내항공사 수송현황 20200326.xlsx
# 김포공항 국내항공사 수송현황 20200327.xlsx
# 김포공항 국내항공사 수송현황 20200328.xlsx
# 김포공항 국내항공사 수송현황 20200329.xlsx
# 김포공항 국내항공사 수송현황 20200330.xlsx
# 김포공항 국내항공사 수송현황 20200331.xlsx
# 김포공항 외국항공사 수송현황 20200301.xlsx
# 김포공항 외국항공사 수송현황 20200302.xlsx
# 김포공항 외국항공사 수송현황 20200303.xlsx
# 김포공항 외국항공사 수송현황 20200304.xlsx
# 김포공항 외국항공사 수송현황 20200305.xlsx
# 김포공항 외국항공사 수송현황 20200306.xlsx
# 김포공항 외국항공사 수송현황 20200307.xlsx
# 김포공항 외국항공사 수송현황 20200308.xlsx
# 김포공항 외국항공사 수송현황 20200309.xlsx
# 김포공항 외국항공사 수송현황 20200310.xlsx
# 김포공항 외국항공사 수송현황 20200311.xlsx
# 김포공항 외국항공사 수송현황 20200312.xlsx
# 김포공항 외국항공사 수송현황 20200313.xlsx
# 김포공항 외국항공사 수송현황 20200314.xlsx
# 김포공항 외국항공사 수송현황 20200315.xlsx
# 김포공항 외국항공사 수송현황 20200316.xlsx
# 김포공항 외국항공사 수송현황 20200317.xlsx
# 김포공항 외국항공사 수송현황 20200318.xlsx
# 김포공항 외국항공사 수송현황 20200319.xlsx
# 김포공항 외국항공사 수송현황 20200320.xlsx
# 김포공항 외국항공사 수송현황 20200321.xlsx
# 김포공항 외국항공사 수송현황 20200322.xlsx
# 김포공항 외국항공사 수송현황 20200323.xlsx
# 김포공항 외국항공사 수송현황 20200324.xlsx
# 김포공항 외국항공사 수송현황 20200325.xlsx
# 김포공항 외국항공사 수송현황 20200326.xlsx
# 김포공항 외국항공사 수송현황 20200327.xlsx
# 김포공항 외국항공사 수송현황 20200328.xlsx
# 김포공항 외국항공사 수송현황 20200329.xlsx
# 김포공항 외국항공사 수송현황 20200330.xlsx
# 김포공항 외국항공사 수송현황 20200331.xlsx
# 김포공항 국내항공사 수송현황 20200401.xlsx
# 김포공항 국내항공사 수송현황 20200402.xlsx
# 김포공항 국내항공사 수송현황 20200403.xlsx
# 김포공항 국내항공사 수송현황 20200404.xlsx
# 김포공항 국내항공사 수송현황 20200405.xlsx
# 김포공항 국내항공사 수송현황 20200406.xlsx
# 김포공항 국내항공사 수송현황 20200407.xlsx
# 김포공항 국내항공사 수송현황 20200408.xlsx
# 김포공항 국내항공사 수송현황 20200409.xlsx
# 김포공항 국내항공사 수송현황 20200410.xlsx
# 김포공항 국내항공사 수송현황 20200411.xlsx
# 김포공항 국내항공사 수송현황 20200412.xlsx
# 김포공항 국내항공사 수송현황 20200413.xlsx
# 김포공항 국내항공사 수송현황 20200414.xlsx
# 김포공항 국내항공사 수송현황 20200415.xlsx
# 김포공항 국내항공사 수송현황 20200416.xlsx
# 김포공항 국내항공사 수송현황 20200417.xlsx
# 김포공항 국내항공사 수송현황 20200418.xlsx
# 김포공항 국내항공사 수송현황 20200419.xlsx
# 김포공항 국내항공사 수송현황 20200420.xlsx
# 김포공항 국내항공사 수송현황 20200421.xlsx
# 김포공항 국내항공사 수송현황 20200422.xlsx
# 김포공항 국내항공사 수송현황 20200423.xlsx
# 김포공항 국내항공사 수송현황 20200424.xlsx
# 김포공항 국내항공사 수송현황 20200425.xlsx
# 김포공항 국내항공사 수송현황 20200426.xlsx
# 김포공항 국내항공사 수송현황 20200427.xlsx
# 김포공항 국내항공사 수송현황 20200428.xlsx
# 김포공항 국내항공사 수송현황 20200429.xlsx
# 김포공항 국내항공사 수송현황 20200430.xlsx
# 김포공항 외국항공사 수송현황 20200401.xlsx
# 김포공항 외국항공사 수송현황 20200402.xlsx
# 김포공항 외국항공사 수송현황 20200403.xlsx
# 김포공항 외국항공사 수송현황 20200404.xlsx
# 김포공항 외국항공사 수송현황 20200405.xlsx
# 김포공항 외국항공사 수송현황 20200406.xlsx
# 김포공항 외국항공사 수송현황 20200407.xlsx
# 김포공항 외국항공사 수송현황 20200408.xlsx
# 김포공항 외국항공사 수송현황 20200409.xlsx
# 김포공항 외국항공사 수송현황 20200410.xlsx
# 김포공항 외국항공사 수송현황 20200411.xlsx
# 김포공항 외국항공사 수송현황 20200412.xlsx
# 김포공항 외국항공사 수송현황 20200413.xlsx
# 김포공항 외국항공사 수송현황 20200414.xlsx
# 김포공항 외국항공사 수송현황 20200415.xlsx
# 김포공항 외국항공사 수송현황 20200416.xlsx
# 김포공항 외국항공사 수송현황 20200417.xlsx
# 김포공항 외국항공사 수송현황 20200418.xlsx
# 김포공항 외국항공사 수송현황 20200419.xlsx
# 김포공항 외국항공사 수송현황 20200420.xlsx
# 김포공항 외국항공사 수송현황 20200421.xlsx
# 김포공항 외국항공사 수송현황 20200422.xlsx
# 김포공항 외국항공사 수송현황 20200423.xlsx
# 김포공항 외국항공사 수송현황 20200424.xlsx
# 김포공항 외국항공사 수송현황 20200425.xlsx
# 김포공항 외국항공사 수송현황 20200426.xlsx
# 김포공항 외국항공사 수송현황 20200427.xlsx
# 김포공항 외국항공사 수송현황 20200428.xlsx
# 김포공항 외국항공사 수송현황 20200429.xlsx
# 김포공항 외국항공사 수송현황 20200430.xlsx
# 김포공항 국내항공사 수송현황 20200501.xlsx
# 김포공항 국내항공사 수송현황 20200502.xlsx
# 김포공항 국내항공사 수송현황 20200503.xlsx
# 김포공항 국내항공사 수송현황 20200504.xlsx
# 김포공항 국내항공사 수송현황 20200505.xlsx
# 김포공항 외국항공사 수송현황 20200501.xlsx
# 김포공항 외국항공사 수송현황 20200502.xlsx
# 김포공항 외국항공사 수송현황 20200503.xlsx
# 김포공항 외국항공사 수송현황 20200504.xlsx
# 김포공항 외국항공사 수송현황 20200505.xlsx
# 인천공항 국내항공사 수송현황 20191201.xlsx
# 인천공항 국내항공사 수송현황 20191202.xlsx
# 인천공항 국내항공사 수송현황 20191203.xlsx
# 인천공항 국내항공사 수송현황 20191204.xlsx
# 인천공항 국내항공사 수송현황 20191205.xlsx
# 인천공항 국내항공사 수송현황 20191206.xlsx
# 인천공항 국내항공사 수송현황 20191207.xlsx
# 인천공항 국내항공사 수송현황 20191208.xlsx
# 인천공항 국내항공사 수송현황 20191209.xlsx
# 인천공항 국내항공사 수송현황 20191210.xlsx
# 인천공항 국내항공사 수송현황 20191211.xlsx
# 인천공항 국내항공사 수송현황 20191212.xlsx
# 인천공항 국내항공사 수송현황 20191213.xlsx
# 인천공항 국내항공사 수송현황 20191214.xlsx
# 인천공항 국내항공사 수송현황 20191215.xlsx
# 인천공항 국내항공사 수송현황 20191216.xlsx
# 인천공항 국내항공사 수송현황 20191217.xlsx
# 인천공항 국내항공사 수송현황 20191218.xlsx
# 인천공항 국내항공사 수송현황 20191219.xlsx
# 인천공항 국내항공사 수송현황 20191220.xlsx
# 인천공항 국내항공사 수송현황 20191221.xlsx
# 인천공항 국내항공사 수송현황 20191222.xlsx
# 인천공항 국내항공사 수송현황 20191223.xlsx
# 인천공항 국내항공사 수송현황 20191224.xlsx
# 인천공항 국내항공사 수송현황 20191225.xlsx
# 인천공항 국내항공사 수송현황 20191226.xlsx
# 인천공항 국내항공사 수송현황 20191227.xlsx
# 인천공항 국내항공사 수송현황 20191228.xlsx
# 인천공항 국내항공사 수송현황 20191229.xlsx
# 인천공항 국내항공사 수송현황 20191230.xlsx
# 인천공항 국내항공사 수송현황 20191231.xlsx
# 인천공항 외국항공사 수송현황 20191201.xlsx
# 인천공항 외국항공사 수송현황 20191202.xlsx
# 인천공항 외국항공사 수송현황 20191203.xlsx
# 인천공항 외국항공사 수송현황 20191204.xlsx
# 인천공항 외국항공사 수송현황 20191205.xlsx
# 인천공항 외국항공사 수송현황 20191206.xlsx
# 인천공항 외국항공사 수송현황 20191207.xlsx
# 인천공항 외국항공사 수송현황 20191208.xlsx
# 인천공항 외국항공사 수송현황 20191209.xlsx
# 인천공항 외국항공사 수송현황 20191210.xlsx
# 인천공항 외국항공사 수송현황 20191211.xlsx
# 인천공항 외국항공사 수송현황 20191212.xlsx
# 인천공항 외국항공사 수송현황 20191213.xlsx
# 인천공항 외국항공사 수송현황 20191214.xlsx
# 인천공항 외국항공사 수송현황 20191215.xlsx
# 인천공항 외국항공사 수송현황 20191216.xlsx
# 인천공항 외국항공사 수송현황 20191217.xlsx
# 인천공항 외국항공사 수송현황 20191218.xlsx
# 인천공항 외국항공사 수송현황 20191219.xlsx
# 인천공항 외국항공사 수송현황 20191220.xlsx
# 인천공항 외국항공사 수송현황 20191221.xlsx
# 인천공항 외국항공사 수송현황 20191222.xlsx
# 인천공항 외국항공사 수송현황 20191223.xlsx
# 인천공항 외국항공사 수송현황 20191224.xlsx
# 인천공항 외국항공사 수송현황 20191225.xlsx
# 인천공항 외국항공사 수송현황 20191226.xlsx
# 인천공항 외국항공사 수송현황 20191227.xlsx
# 인천공항 외국항공사 수송현황 20191228.xlsx
# 인천공항 외국항공사 수송현황 20191229.xlsx
# 인천공항 외국항공사 수송현황 20191230.xlsx
# 인천공항 외국항공사 수송현황 20191231.xlsx
# 인천공항 국내항공사 수송현황 20200101.xlsx
# 인천공항 국내항공사 수송현황 20200102.xlsx
# 인천공항 국내항공사 수송현황 20200103.xlsx
# 인천공항 국내항공사 수송현황 20200104.xlsx
# 인천공항 국내항공사 수송현황 20200105.xlsx
# 인천공항 국내항공사 수송현황 20200106.xlsx
# 인천공항 국내항공사 수송현황 20200107.xlsx
# 인천공항 국내항공사 수송현황 20200108.xlsx
# 인천공항 국내항공사 수송현황 20200109.xlsx
# 인천공항 국내항공사 수송현황 20200110.xlsx
# 인천공항 국내항공사 수송현황 20200111.xlsx
# 인천공항 국내항공사 수송현황 20200112.xlsx
# 인천공항 국내항공사 수송현황 20200113.xlsx
# 인천공항 국내항공사 수송현황 20200114.xlsx
# 인천공항 국내항공사 수송현황 20200115.xlsx
# 인천공항 국내항공사 수송현황 20200116.xlsx
# 인천공항 국내항공사 수송현황 20200117.xlsx
# 인천공항 국내항공사 수송현황 20200118.xlsx
# 인천공항 국내항공사 수송현황 20200119.xlsx
# 인천공항 국내항공사 수송현황 20200120.xlsx
# 인천공항 국내항공사 수송현황 20200121.xlsx
# 인천공항 국내항공사 수송현황 20200122.xlsx
# 인천공항 국내항공사 수송현황 20200123.xlsx
# 인천공항 국내항공사 수송현황 20200124.xlsx
# 인천공항 국내항공사 수송현황 20200125.xlsx
# 인천공항 국내항공사 수송현황 20200126.xlsx
# 인천공항 국내항공사 수송현황 20200127.xlsx
# 인천공항 국내항공사 수송현황 20200128.xlsx
# 인천공항 국내항공사 수송현황 20200129.xlsx
# 인천공항 국내항공사 수송현황 20200130.xlsx
# 인천공항 국내항공사 수송현황 20200131.xlsx
# 인천공항 외국항공사 수송현황 20200101.xlsx
# 인천공항 외국항공사 수송현황 20200102.xlsx
# 인천공항 외국항공사 수송현황 20200103.xlsx
# 인천공항 외국항공사 수송현황 20200104.xlsx
# 인천공항 외국항공사 수송현황 20200105.xlsx
# 인천공항 외국항공사 수송현황 20200106.xlsx
# 인천공항 외국항공사 수송현황 20200107.xlsx
# 인천공항 외국항공사 수송현황 20200108.xlsx
# 인천공항 외국항공사 수송현황 20200109.xlsx
# 인천공항 외국항공사 수송현황 20200110.xlsx
# 인천공항 외국항공사 수송현황 20200111.xlsx
# 인천공항 외국항공사 수송현황 20200112.xlsx
# 인천공항 외국항공사 수송현황 20200113.xlsx
# 인천공항 외국항공사 수송현황 20200114.xlsx
# 인천공항 외국항공사 수송현황 20200115.xlsx
# 인천공항 외국항공사 수송현황 20200116.xlsx
# 인천공항 외국항공사 수송현황 20200117.xlsx
# 인천공항 외국항공사 수송현황 20200118.xlsx
# 인천공항 외국항공사 수송현황 20200119.xlsx
# 인천공항 외국항공사 수송현황 20200120.xlsx
# 인천공항 외국항공사 수송현황 20200121.xlsx
# 인천공항 외국항공사 수송현황 20200122.xlsx
# 인천공항 외국항공사 수송현황 20200123.xlsx
# 인천공항 외국항공사 수송현황 20200124.xlsx
# 인천공항 외국항공사 수송현황 20200125.xlsx
# 인천공항 외국항공사 수송현황 20200126.xlsx
# 인천공항 외국항공사 수송현황 20200127.xlsx
# 인천공항 외국항공사 수송현황 20200128.xlsx
# 인천공항 외국항공사 수송현황 20200129.xlsx
# 인천공항 외국항공사 수송현황 20200130.xlsx
# 인천공항 외국항공사 수송현황 20200131.xlsx
# 인천공항 국내항공사 수송현황 20200201.xlsx
# 인천공항 국내항공사 수송현황 20200202.xlsx
# 인천공항 국내항공사 수송현황 20200203.xlsx
# 인천공항 국내항공사 수송현황 20200204.xlsx
# 인천공항 국내항공사 수송현황 20200205.xlsx
# 인천공항 국내항공사 수송현황 20200206.xlsx
# 인천공항 국내항공사 수송현황 20200207.xlsx
# 인천공항 국내항공사 수송현황 20200208.xlsx
# 인천공항 국내항공사 수송현황 20200209.xlsx
# 인천공항 국내항공사 수송현황 20200210.xlsx
# 인천공항 국내항공사 수송현황 20200211.xlsx
# 인천공항 국내항공사 수송현황 20200212.xlsx
# 인천공항 국내항공사 수송현황 20200213.xlsx
# 인천공항 국내항공사 수송현황 20200214.xlsx
# 인천공항 국내항공사 수송현황 20200215.xlsx
# 인천공항 국내항공사 수송현황 20200216.xlsx
# 인천공항 국내항공사 수송현황 20200217.xlsx
# 인천공항 국내항공사 수송현황 20200218.xlsx
# 인천공항 국내항공사 수송현황 20200219.xlsx
# 인천공항 국내항공사 수송현황 20200220.xlsx
# 인천공항 국내항공사 수송현황 20200221.xlsx
# 인천공항 국내항공사 수송현황 20200222.xlsx
# 인천공항 국내항공사 수송현황 20200223.xlsx
# 인천공항 국내항공사 수송현황 20200224.xlsx
# 인천공항 국내항공사 수송현황 20200225.xlsx
# 인천공항 국내항공사 수송현황 20200226.xlsx
# 인천공항 국내항공사 수송현황 20200227.xlsx
# 인천공항 국내항공사 수송현황 20200228.xlsx
# 인천공항 국내항공사 수송현황 20200229.xlsx
# 인천공항 외국항공사 수송현황 20200201.xlsx
# 인천공항 외국항공사 수송현황 20200202.xlsx
# 인천공항 외국항공사 수송현황 20200203.xlsx
# 인천공항 외국항공사 수송현황 20200204.xlsx
# 인천공항 외국항공사 수송현황 20200205.xlsx
# 인천공항 외국항공사 수송현황 20200206.xlsx
# 인천공항 외국항공사 수송현황 20200207.xlsx
# 인천공항 외국항공사 수송현황 20200208.xlsx
# 인천공항 외국항공사 수송현황 20200209.xlsx
# 인천공항 외국항공사 수송현황 20200210.xlsx
# 인천공항 외국항공사 수송현황 20200211.xlsx
# 인천공항 외국항공사 수송현황 20200212.xlsx
# 인천공항 외국항공사 수송현황 20200213.xlsx
# 인천공항 외국항공사 수송현황 20200214.xlsx
# 인천공항 외국항공사 수송현황 20200215.xlsx
# 인천공항 외국항공사 수송현황 20200216.xlsx
# 인천공항 외국항공사 수송현황 20200217.xlsx
# 인천공항 외국항공사 수송현황 20200218.xlsx
# 인천공항 외국항공사 수송현황 20200219.xlsx
# 인천공항 외국항공사 수송현황 20200220.xlsx
# 인천공항 외국항공사 수송현황 20200221.xlsx
# 인천공항 외국항공사 수송현황 20200222.xlsx
# 인천공항 외국항공사 수송현황 20200223.xlsx
# 인천공항 외국항공사 수송현황 20200224.xlsx
# 인천공항 외국항공사 수송현황 20200225.xlsx
# 인천공항 외국항공사 수송현황 20200226.xlsx
# 인천공항 외국항공사 수송현황 20200227.xlsx
# 인천공항 외국항공사 수송현황 20200228.xlsx
# 인천공항 외국항공사 수송현황 20200229.xlsx
# 인천공항 국내항공사 수송현황 20200301.xlsx
# 인천공항 국내항공사 수송현황 20200302.xlsx
# 인천공항 국내항공사 수송현황 20200303.xlsx
# 인천공항 국내항공사 수송현황 20200304.xlsx
# 인천공항 국내항공사 수송현황 20200305.xlsx
# 인천공항 국내항공사 수송현황 20200306.xlsx
# 인천공항 국내항공사 수송현황 20200307.xlsx
# 인천공항 국내항공사 수송현황 20200308.xlsx
# 인천공항 국내항공사 수송현황 20200309.xlsx
# 인천공항 국내항공사 수송현황 20200310.xlsx
# 인천공항 국내항공사 수송현황 20200311.xlsx
# 인천공항 국내항공사 수송현황 20200312.xlsx
# 인천공항 국내항공사 수송현황 20200313.xlsx
# 인천공항 국내항공사 수송현황 20200314.xlsx
# 인천공항 국내항공사 수송현황 20200315.xlsx
# 인천공항 국내항공사 수송현황 20200316.xlsx
# 인천공항 국내항공사 수송현황 20200317.xlsx
# 인천공항 국내항공사 수송현황 20200318.xlsx
# 인천공항 국내항공사 수송현황 20200319.xlsx
# 인천공항 국내항공사 수송현황 20200320.xlsx
# 인천공항 국내항공사 수송현황 20200321.xlsx
# 인천공항 국내항공사 수송현황 20200322.xlsx
# 인천공항 국내항공사 수송현황 20200323.xlsx
# 인천공항 국내항공사 수송현황 20200324.xlsx
# 인천공항 국내항공사 수송현황 20200325.xlsx
# 인천공항 국내항공사 수송현황 20200326.xlsx
# 인천공항 국내항공사 수송현황 20200327.xlsx
# 인천공항 국내항공사 수송현황 20200328.xlsx
# 인천공항 국내항공사 수송현황 20200329.xlsx
# 인천공항 국내항공사 수송현황 20200330.xlsx
# 인천공항 국내항공사 수송현황 20200331.xlsx
# 인천공항 외국항공사 수송현황 20200301.xlsx
# 인천공항 외국항공사 수송현황 20200302.xlsx
# 인천공항 외국항공사 수송현황 20200303.xlsx
# 인천공항 외국항공사 수송현황 20200304.xlsx
# 인천공항 외국항공사 수송현황 20200305.xlsx
# 인천공항 외국항공사 수송현황 20200306.xlsx
# 인천공항 외국항공사 수송현황 20200307.xlsx
# 인천공항 외국항공사 수송현황 20200308.xlsx
# 인천공항 외국항공사 수송현황 20200309.xlsx
# 인천공항 외국항공사 수송현황 20200310.xlsx
# 인천공항 외국항공사 수송현황 20200311.xlsx
# 인천공항 외국항공사 수송현황 20200312.xlsx
# 인천공항 외국항공사 수송현황 20200313.xlsx
# 인천공항 외국항공사 수송현황 20200314.xlsx
# 인천공항 외국항공사 수송현황 20200315.xlsx
# 인천공항 외국항공사 수송현황 20200316.xlsx
# 인천공항 외국항공사 수송현황 20200317.xlsx
# 인천공항 외국항공사 수송현황 20200318.xlsx
# 인천공항 외국항공사 수송현황 20200319.xlsx
# 인천공항 외국항공사 수송현황 20200320.xlsx
# 인천공항 외국항공사 수송현황 20200321.xlsx
# 인천공항 외국항공사 수송현황 20200322.xlsx
# 인천공항 외국항공사 수송현황 20200323.xlsx
# 인천공항 외국항공사 수송현황 20200324.xlsx
# 인천공항 외국항공사 수송현황 20200325.xlsx
# 인천공항 외국항공사 수송현황 20200326.xlsx
# 인천공항 외국항공사 수송현황 20200327.xlsx
# 인천공항 외국항공사 수송현황 20200328.xlsx
# 인천공항 외국항공사 수송현황 20200329.xlsx
# 인천공항 외국항공사 수송현황 20200330.xlsx
# 인천공항 외국항공사 수송현황 20200331.xlsx
# 인천공항 국내항공사 수송현황 20200401.xlsx
# 인천공항 국내항공사 수송현황 20200402.xlsx
# 인천공항 국내항공사 수송현황 20200403.xlsx
# 인천공항 국내항공사 수송현황 20200404.xlsx
# 인천공항 국내항공사 수송현황 20200405.xlsx
# 인천공항 국내항공사 수송현황 20200406.xlsx
# 인천공항 국내항공사 수송현황 20200407.xlsx
# 인천공항 국내항공사 수송현황 20200408.xlsx
# 인천공항 국내항공사 수송현황 20200409.xlsx
# 인천공항 국내항공사 수송현황 20200410.xlsx
# 인천공항 국내항공사 수송현황 20200411.xlsx
# 인천공항 국내항공사 수송현황 20200412.xlsx
# 인천공항 국내항공사 수송현황 20200413.xlsx
# 인천공항 국내항공사 수송현황 20200414.xlsx
# 인천공항 국내항공사 수송현황 20200415.xlsx
# 인천공항 국내항공사 수송현황 20200416.xlsx
# 인천공항 국내항공사 수송현황 20200417.xlsx
# 인천공항 국내항공사 수송현황 20200418.xlsx
# 인천공항 국내항공사 수송현황 20200419.xlsx
# 인천공항 국내항공사 수송현황 20200420.xlsx
# 인천공항 국내항공사 수송현황 20200421.xlsx
# 인천공항 국내항공사 수송현황 20200422.xlsx
# 인천공항 국내항공사 수송현황 20200423.xlsx
# 인천공항 국내항공사 수송현황 20200424.xlsx
# 인천공항 국내항공사 수송현황 20200425.xlsx
# 인천공항 국내항공사 수송현황 20200426.xlsx
# 인천공항 국내항공사 수송현황 20200427.xlsx
# 인천공항 국내항공사 수송현황 20200428.xlsx
# 인천공항 국내항공사 수송현황 20200429.xlsx
# 인천공항 국내항공사 수송현황 20200430.xlsx
# 인천공항 외국항공사 수송현황 20200401.xlsx
# 인천공항 외국항공사 수송현황 20200402.xlsx
# 인천공항 외국항공사 수송현황 20200403.xlsx
# 인천공항 외국항공사 수송현황 20200404.xlsx
# 인천공항 외국항공사 수송현황 20200405.xlsx
# 인천공항 외국항공사 수송현황 20200406.xlsx
# 인천공항 외국항공사 수송현황 20200407.xlsx
# 인천공항 외국항공사 수송현황 20200408.xlsx
# 인천공항 외국항공사 수송현황 20200409.xlsx
# 인천공항 외국항공사 수송현황 20200410.xlsx
# 인천공항 외국항공사 수송현황 20200411.xlsx
# 인천공항 외국항공사 수송현황 20200412.xlsx
# 인천공항 외국항공사 수송현황 20200413.xlsx
# 인천공항 외국항공사 수송현황 20200414.xlsx
# 인천공항 외국항공사 수송현황 20200415.xlsx
# 인천공항 외국항공사 수송현황 20200416.xlsx
# 인천공항 외국항공사 수송현황 20200417.xlsx
# 인천공항 외국항공사 수송현황 20200418.xlsx
# 인천공항 외국항공사 수송현황 20200419.xlsx
# 인천공항 외국항공사 수송현황 20200420.xlsx
# 인천공항 외국항공사 수송현황 20200421.xlsx
# 인천공항 외국항공사 수송현황 20200422.xlsx
# 인천공항 외국항공사 수송현황 20200423.xlsx
# 인천공항 외국항공사 수송현황 20200424.xlsx
# 인천공항 외국항공사 수송현황 20200425.xlsx
# 인천공항 외국항공사 수송현황 20200426.xlsx
# 인천공항 외국항공사 수송현황 20200427.xlsx
# 인천공항 외국항공사 수송현황 20200428.xlsx
# 인천공항 외국항공사 수송현황 20200429.xlsx
# 인천공항 외국항공사 수송현황 20200430.xlsx
# 인천공항 국내항공사 수송현황 20200501.xlsx
# 인천공항 국내항공사 수송현황 20200502.xlsx
# 인천공항 국내항공사 수송현황 20200503.xlsx
# 인천공항 국내항공사 수송현황 20200504.xlsx
# 인천공항 국내항공사 수송현황 20200505.xlsx
# 인천공항 외국항공사 수송현황 20200501.xlsx
# 인천공항 외국항공사 수송현황 20200502.xlsx
# 인천공항 외국항공사 수송현황 20200503.xlsx
# 인천공항 외국항공사 수송현황 20200504.xlsx
# 인천공항 외국항공사 수송현황 20200505.xlsx
# 제주공항 국내항공사 수송현황 20191201.xlsx
# 제주공항 국내항공사 수송현황 20191202.xlsx
# 제주공항 국내항공사 수송현황 20191203.xlsx
# 제주공항 국내항공사 수송현황 20191204.xlsx
# 제주공항 국내항공사 수송현황 20191205.xlsx
# 제주공항 국내항공사 수송현황 20191206.xlsx
# 제주공항 국내항공사 수송현황 20191207.xlsx
# 제주공항 국내항공사 수송현황 20191208.xlsx
# 제주공항 국내항공사 수송현황 20191209.xlsx
# 제주공항 국내항공사 수송현황 20191210.xlsx
# 제주공항 국내항공사 수송현황 20191211.xlsx
# 제주공항 국내항공사 수송현황 20191212.xlsx
# 제주공항 국내항공사 수송현황 20191213.xlsx
# 제주공항 국내항공사 수송현황 20191214.xlsx
# 제주공항 국내항공사 수송현황 20191215.xlsx
# 제주공항 국내항공사 수송현황 20191216.xlsx
# 제주공항 국내항공사 수송현황 20191217.xlsx
# 제주공항 국내항공사 수송현황 20191218.xlsx
# 제주공항 국내항공사 수송현황 20191219.xlsx
# 제주공항 국내항공사 수송현황 20191220.xlsx
# 제주공항 국내항공사 수송현황 20191221.xlsx
# 제주공항 국내항공사 수송현황 20191222.xlsx
# 제주공항 국내항공사 수송현황 20191223.xlsx
# 제주공항 국내항공사 수송현황 20191224.xlsx
# 제주공항 국내항공사 수송현황 20191225.xlsx
# 제주공항 국내항공사 수송현황 20191226.xlsx
# 제주공항 국내항공사 수송현황 20191227.xlsx
# 제주공항 국내항공사 수송현황 20191228.xlsx
# 제주공항 국내항공사 수송현황 20191229.xlsx
# ...
# 무안공항 국내항공사 수송현황 20200410.xlsx
# 무안공항 국내항공사 수송현황 20200411.xlsx
# 무안공항 국내항공사 수송현황 20200412.xlsx
# 무안공항 국내항공사 수송현황 20200413.xlsx
# 무안공항 국내항공사 수송현황 20200414.xlsx
# 무안공항 국내항공사 수송현황 20200415.xlsx
# 무안공항 국내항공사 수송현황 20200416.xlsx
# 무안공항 국내항공사 수송현황 20200417.xlsx
# 무안공항 국내항공사 수송현황 20200418.xlsx
# 무안공항 국내항공사 수송현황 20200419.xlsx
# 무안공항 국내항공사 수송현황 20200420.xlsx
# 무안공항 국내항공사 수송현황 20200421.xlsx
# 무안공항 국내항공사 수송현황 20200422.xlsx
# 무안공항 국내항공사 수송현황 20200423.xlsx
# 무안공항 국내항공사 수송현황 20200424.xlsx
# 무안공항 국내항공사 수송현황 20200425.xlsx
# 무안공항 국내항공사 수송현황 20200426.xlsx
# 무안공항 국내항공사 수송현황 20200427.xlsx
# 무안공항 국내항공사 수송현황 20200428.xlsx
# 무안공항 국내항공사 수송현황 20200429.xlsx
# 무안공항 국내항공사 수송현황 20200430.xlsx
# 무안공항 외국항공사 수송현황 20200401.xlsx
# 무안공항 외국항공사 수송현황 20200402.xlsx
# 무안공항 외국항공사 수송현황 20200403.xlsx
# 무안공항 외국항공사 수송현황 20200404.xlsx
# 무안공항 외국항공사 수송현황 20200405.xlsx
# 무안공항 외국항공사 수송현황 20200406.xlsx
# 무안공항 외국항공사 수송현황 20200407.xlsx
# 무안공항 외국항공사 수송현황 20200408.xlsx
# 무안공항 외국항공사 수송현황 20200409.xlsx
# 무안공항 외국항공사 수송현황 20200410.xlsx
# 무안공항 외국항공사 수송현황 20200411.xlsx
# 무안공항 외국항공사 수송현황 20200412.xlsx
# 무안공항 외국항공사 수송현황 20200413.xlsx
# 무안공항 외국항공사 수송현황 20200414.xlsx
# 무안공항 외국항공사 수송현황 20200415.xlsx
# 무안공항 외국항공사 수송현황 20200416.xlsx
# 무안공항 외국항공사 수송현황 20200417.xlsx
# 무안공항 외국항공사 수송현황 20200418.xlsx
# 무안공항 외국항공사 수송현황 20200419.xlsx
# 무안공항 외국항공사 수송현황 20200420.xlsx
# 무안공항 외국항공사 수송현황 20200421.xlsx
# 무안공항 외국항공사 수송현황 20200422.xlsx
# 무안공항 외국항공사 수송현황 20200423.xlsx
# 무안공항 외국항공사 수송현황 20200424.xlsx
# 무안공항 외국항공사 수송현황 20200425.xlsx
# 무안공항 외국항공사 수송현황 20200426.xlsx
# 무안공항 외국항공사 수송현황 20200427.xlsx
# 무안공항 외국항공사 수송현황 20200428.xlsx
# 무안공항 외국항공사 수송현황 20200429.xlsx
# 무안공항 외국항공사 수송현황 20200430.xlsx
# 무안공항 국내항공사 수송현황 20200501.xlsx
# 무안공항 국내항공사 수송현황 20200502.xlsx
# 무안공항 국내항공사 수송현황 20200503.xlsx
# 무안공항 국내항공사 수송현황 20200504.xlsx
# 무안공항 국내항공사 수송현황 20200505.xlsx
# 무안공항 외국항공사 수송현황 20200501.xlsx
# 무안공항 외국항공사 수송현황 20200502.xlsx
# 무안공항 외국항공사 수송현황 20200503.xlsx
# 무안공항 외국항공사 수송현황 20200504.xlsx
# 무안공항 외국항공사 수송현황 20200505.xlsx
# 양양공항 국내항공사 수송현황 20191201.xlsx
# 양양공항 국내항공사 수송현황 20191202.xlsx
# 양양공항 국내항공사 수송현황 20191203.xlsx
# 양양공항 국내항공사 수송현황 20191204.xlsx
# 양양공항 국내항공사 수송현황 20191205.xlsx
# 양양공항 국내항공사 수송현황 20191206.xlsx
# 양양공항 국내항공사 수송현황 20191207.xlsx
# 양양공항 국내항공사 수송현황 20191208.xlsx
# 양양공항 국내항공사 수송현황 20191209.xlsx
# 양양공항 국내항공사 수송현황 20191210.xlsx
# 양양공항 국내항공사 수송현황 20191211.xlsx
# 양양공항 국내항공사 수송현황 20191212.xlsx
# 양양공항 국내항공사 수송현황 20191213.xlsx
# 양양공항 국내항공사 수송현황 20191214.xlsx
# 양양공항 국내항공사 수송현황 20191215.xlsx
# 양양공항 국내항공사 수송현황 20191216.xlsx
# 양양공항 국내항공사 수송현황 20191217.xlsx
# 양양공항 국내항공사 수송현황 20191218.xlsx
# 양양공항 국내항공사 수송현황 20191219.xlsx
# 양양공항 국내항공사 수송현황 20191220.xlsx
# 양양공항 국내항공사 수송현황 20191221.xlsx
# 양양공항 국내항공사 수송현황 20191222.xlsx
# 양양공항 국내항공사 수송현황 20191223.xlsx
# 양양공항 국내항공사 수송현황 20191224.xlsx
# 양양공항 국내항공사 수송현황 20191225.xlsx
# 양양공항 국내항공사 수송현황 20191226.xlsx
# 양양공항 국내항공사 수송현황 20191227.xlsx
# 양양공항 국내항공사 수송현황 20191228.xlsx
# 양양공항 국내항공사 수송현황 20191229.xlsx
# 양양공항 국내항공사 수송현황 20191230.xlsx
# 양양공항 국내항공사 수송현황 20191231.xlsx
# 양양공항 외국항공사 수송현황 20191201.xlsx
# 양양공항 외국항공사 수송현황 20191202.xlsx
# 양양공항 외국항공사 수송현황 20191203.xlsx
# 양양공항 외국항공사 수송현황 20191204.xlsx
# 양양공항 외국항공사 수송현황 20191205.xlsx
# 양양공항 외국항공사 수송현황 20191206.xlsx
# 양양공항 외국항공사 수송현황 20191207.xlsx
# 양양공항 외국항공사 수송현황 20191208.xlsx
# 양양공항 외국항공사 수송현황 20191209.xlsx
# 양양공항 외국항공사 수송현황 20191210.xlsx
# 양양공항 외국항공사 수송현황 20191211.xlsx
# 양양공항 외국항공사 수송현황 20191212.xlsx
# 양양공항 외국항공사 수송현황 20191213.xlsx
# 양양공항 외국항공사 수송현황 20191214.xlsx
# 양양공항 외국항공사 수송현황 20191215.xlsx
# 양양공항 외국항공사 수송현황 20191216.xlsx
# 양양공항 외국항공사 수송현황 20191217.xlsx
# 양양공항 외국항공사 수송현황 20191218.xlsx
# 양양공항 외국항공사 수송현황 20191219.xlsx
# 양양공항 외국항공사 수송현황 20191220.xlsx
# 양양공항 외국항공사 수송현황 20191221.xlsx
# 양양공항 외국항공사 수송현황 20191222.xlsx
# 양양공항 외국항공사 수송현황 20191223.xlsx
# 양양공항 외국항공사 수송현황 20191224.xlsx
# 양양공항 외국항공사 수송현황 20191225.xlsx
# 양양공항 외국항공사 수송현황 20191226.xlsx
# 양양공항 외국항공사 수송현황 20191227.xlsx
# 양양공항 외국항공사 수송현황 20191228.xlsx
# 양양공항 외국항공사 수송현황 20191229.xlsx
# 양양공항 외국항공사 수송현황 20191230.xlsx
# 양양공항 외국항공사 수송현황 20191231.xlsx
# 양양공항 국내항공사 수송현황 20200101.xlsx
# 양양공항 국내항공사 수송현황 20200102.xlsx
# 양양공항 국내항공사 수송현황 20200103.xlsx
# 양양공항 국내항공사 수송현황 20200104.xlsx
# 양양공항 국내항공사 수송현황 20200105.xlsx
# 양양공항 국내항공사 수송현황 20200106.xlsx
# 양양공항 국내항공사 수송현황 20200107.xlsx
# 양양공항 국내항공사 수송현황 20200108.xlsx
# 양양공항 국내항공사 수송현황 20200109.xlsx
# 양양공항 국내항공사 수송현황 20200110.xlsx
# 양양공항 국내항공사 수송현황 20200111.xlsx
# 양양공항 국내항공사 수송현황 20200112.xlsx
# 양양공항 국내항공사 수송현황 20200113.xlsx
# 양양공항 국내항공사 수송현황 20200114.xlsx
# 양양공항 국내항공사 수송현황 20200115.xlsx
# 양양공항 국내항공사 수송현황 20200116.xlsx
# 양양공항 국내항공사 수송현황 20200117.xlsx
# 양양공항 국내항공사 수송현황 20200118.xlsx
# 양양공항 국내항공사 수송현황 20200119.xlsx
# 양양공항 국내항공사 수송현황 20200120.xlsx
# 양양공항 국내항공사 수송현황 20200121.xlsx
# 양양공항 국내항공사 수송현황 20200122.xlsx
# 양양공항 국내항공사 수송현황 20200123.xlsx
# 양양공항 국내항공사 수송현황 20200124.xlsx
# 양양공항 국내항공사 수송현황 20200125.xlsx
# 양양공항 국내항공사 수송현황 20200126.xlsx
# 양양공항 국내항공사 수송현황 20200127.xlsx
# 양양공항 국내항공사 수송현황 20200128.xlsx
# 양양공항 국내항공사 수송현황 20200129.xlsx
# 양양공항 국내항공사 수송현황 20200130.xlsx
# 양양공항 국내항공사 수송현황 20200131.xlsx
# 양양공항 외국항공사 수송현황 20200101.xlsx
# 양양공항 외국항공사 수송현황 20200102.xlsx
# 양양공항 외국항공사 수송현황 20200103.xlsx
# 양양공항 외국항공사 수송현황 20200104.xlsx
# 양양공항 외국항공사 수송현황 20200105.xlsx
# 양양공항 외국항공사 수송현황 20200106.xlsx
# 양양공항 외국항공사 수송현황 20200107.xlsx
# 양양공항 외국항공사 수송현황 20200108.xlsx
# 양양공항 외국항공사 수송현황 20200109.xlsx
# 양양공항 외국항공사 수송현황 20200110.xlsx
# 양양공항 외국항공사 수송현황 20200111.xlsx
# 양양공항 외국항공사 수송현황 20200112.xlsx
# 양양공항 외국항공사 수송현황 20200113.xlsx
# 양양공항 외국항공사 수송현황 20200114.xlsx
# 양양공항 외국항공사 수송현황 20200115.xlsx
# 양양공항 외국항공사 수송현황 20200116.xlsx
# 양양공항 외국항공사 수송현황 20200117.xlsx
# 양양공항 외국항공사 수송현황 20200118.xlsx
# 양양공항 외국항공사 수송현황 20200119.xlsx
# 양양공항 외국항공사 수송현황 20200120.xlsx
# 양양공항 외국항공사 수송현황 20200121.xlsx
# 양양공항 외국항공사 수송현황 20200122.xlsx
# 양양공항 외국항공사 수송현황 20200123.xlsx
# 양양공항 외국항공사 수송현황 20200124.xlsx
# 양양공항 외국항공사 수송현황 20200125.xlsx
# 양양공항 외국항공사 수송현황 20200126.xlsx
# 양양공항 외국항공사 수송현황 20200127.xlsx
# 양양공항 외국항공사 수송현황 20200128.xlsx
# 양양공항 외국항공사 수송현황 20200129.xlsx
# 양양공항 외국항공사 수송현황 20200130.xlsx
# 양양공항 외국항공사 수송현황 20200131.xlsx
# 양양공항 국내항공사 수송현황 20200201.xlsx
# 양양공항 국내항공사 수송현황 20200202.xlsx
# 양양공항 국내항공사 수송현황 20200203.xlsx
# 양양공항 국내항공사 수송현황 20200204.xlsx
# 양양공항 국내항공사 수송현황 20200205.xlsx
# 양양공항 국내항공사 수송현황 20200206.xlsx
# 양양공항 국내항공사 수송현황 20200207.xlsx
# 양양공항 국내항공사 수송현황 20200208.xlsx
# 양양공항 국내항공사 수송현황 20200209.xlsx
# 양양공항 국내항공사 수송현황 20200210.xlsx
# 양양공항 국내항공사 수송현황 20200211.xlsx
# 양양공항 국내항공사 수송현황 20200212.xlsx
# 양양공항 국내항공사 수송현황 20200213.xlsx
# 양양공항 국내항공사 수송현황 20200214.xlsx
# 양양공항 국내항공사 수송현황 20200215.xlsx
# 양양공항 국내항공사 수송현황 20200216.xlsx
# 양양공항 국내항공사 수송현황 20200217.xlsx
# 양양공항 국내항공사 수송현황 20200218.xlsx
# 양양공항 국내항공사 수송현황 20200219.xlsx
# 양양공항 국내항공사 수송현황 20200220.xlsx
# 양양공항 국내항공사 수송현황 20200221.xlsx
# 양양공항 국내항공사 수송현황 20200222.xlsx
# 양양공항 국내항공사 수송현황 20200223.xlsx
# 양양공항 국내항공사 수송현황 20200224.xlsx
# 양양공항 국내항공사 수송현황 20200225.xlsx
# 양양공항 국내항공사 수송현황 20200226.xlsx
# 양양공항 국내항공사 수송현황 20200227.xlsx
# 양양공항 국내항공사 수송현황 20200228.xlsx
# 양양공항 국내항공사 수송현황 20200229.xlsx
# 양양공항 외국항공사 수송현황 20200201.xlsx
# 양양공항 외국항공사 수송현황 20200202.xlsx
# 양양공항 외국항공사 수송현황 20200203.xlsx
# 양양공항 외국항공사 수송현황 20200204.xlsx
# 양양공항 외국항공사 수송현황 20200205.xlsx
# 양양공항 외국항공사 수송현황 20200206.xlsx
# 양양공항 외국항공사 수송현황 20200207.xlsx
# 양양공항 외국항공사 수송현황 20200208.xlsx
# 양양공항 외국항공사 수송현황 20200209.xlsx
# 양양공항 외국항공사 수송현황 20200210.xlsx
# 양양공항 외국항공사 수송현황 20200211.xlsx
# 양양공항 외국항공사 수송현황 20200212.xlsx
# 양양공항 외국항공사 수송현황 20200213.xlsx
# 양양공항 외국항공사 수송현황 20200214.xlsx
# 양양공항 외국항공사 수송현황 20200215.xlsx
# 양양공항 외국항공사 수송현황 20200216.xlsx
# 양양공항 외국항공사 수송현황 20200217.xlsx
# 양양공항 외국항공사 수송현황 20200218.xlsx
# 양양공항 외국항공사 수송현황 20200219.xlsx
# 양양공항 외국항공사 수송현황 20200220.xlsx
# 양양공항 외국항공사 수송현황 20200221.xlsx
# 양양공항 외국항공사 수송현황 20200222.xlsx
# 양양공항 외국항공사 수송현황 20200223.xlsx
# 양양공항 외국항공사 수송현황 20200224.xlsx
# 양양공항 외국항공사 수송현황 20200225.xlsx
# 양양공항 외국항공사 수송현황 20200226.xlsx
# 양양공항 외국항공사 수송현황 20200227.xlsx
# 양양공항 외국항공사 수송현황 20200228.xlsx
# 양양공항 외국항공사 수송현황 20200229.xlsx
# 양양공항 국내항공사 수송현황 20200301.xlsx
# 양양공항 국내항공사 수송현황 20200302.xlsx
# 양양공항 국내항공사 수송현황 20200303.xlsx
# 양양공항 국내항공사 수송현황 20200304.xlsx
# 양양공항 국내항공사 수송현황 20200305.xlsx
# 양양공항 국내항공사 수송현황 20200306.xlsx
# 양양공항 국내항공사 수송현황 20200307.xlsx
# 양양공항 국내항공사 수송현황 20200308.xlsx
# 양양공항 국내항공사 수송현황 20200309.xlsx
# 양양공항 국내항공사 수송현황 20200310.xlsx
# 양양공항 국내항공사 수송현황 20200311.xlsx
# 양양공항 국내항공사 수송현황 20200312.xlsx
# 양양공항 국내항공사 수송현황 20200313.xlsx
# 양양공항 국내항공사 수송현황 20200314.xlsx
# 양양공항 국내항공사 수송현황 20200315.xlsx
# 양양공항 국내항공사 수송현황 20200316.xlsx
# 양양공항 국내항공사 수송현황 20200317.xlsx
# 양양공항 국내항공사 수송현황 20200318.xlsx
# 양양공항 국내항공사 수송현황 20200319.xlsx
# 양양공항 국내항공사 수송현황 20200320.xlsx
# 양양공항 국내항공사 수송현황 20200321.xlsx
# 양양공항 국내항공사 수송현황 20200322.xlsx
# 양양공항 국내항공사 수송현황 20200323.xlsx
# 양양공항 국내항공사 수송현황 20200324.xlsx
# 양양공항 국내항공사 수송현황 20200325.xlsx
# 양양공항 국내항공사 수송현황 20200326.xlsx
# 양양공항 국내항공사 수송현황 20200327.xlsx
# 양양공항 국내항공사 수송현황 20200328.xlsx
# 양양공항 국내항공사 수송현황 20200329.xlsx
# 양양공항 국내항공사 수송현황 20200330.xlsx
# 양양공항 국내항공사 수송현황 20200331.xlsx
# 양양공항 외국항공사 수송현황 20200301.xlsx
# 양양공항 외국항공사 수송현황 20200302.xlsx
# 양양공항 외국항공사 수송현황 20200303.xlsx
# 양양공항 외국항공사 수송현황 20200304.xlsx
# 양양공항 외국항공사 수송현황 20200305.xlsx
# 양양공항 외국항공사 수송현황 20200306.xlsx
# 양양공항 외국항공사 수송현황 20200307.xlsx
# 양양공항 외국항공사 수송현황 20200308.xlsx
# 양양공항 외국항공사 수송현황 20200309.xlsx
# 양양공항 외국항공사 수송현황 20200310.xlsx
# 양양공항 외국항공사 수송현황 20200311.xlsx
# 양양공항 외국항공사 수송현황 20200312.xlsx
# 양양공항 외국항공사 수송현황 20200313.xlsx
# 양양공항 외국항공사 수송현황 20200314.xlsx
# 양양공항 외국항공사 수송현황 20200315.xlsx
# 양양공항 외국항공사 수송현황 20200316.xlsx
# 양양공항 외국항공사 수송현황 20200317.xlsx
# 양양공항 외국항공사 수송현황 20200318.xlsx
# 양양공항 외국항공사 수송현황 20200319.xlsx
# 양양공항 외국항공사 수송현황 20200320.xlsx
# 양양공항 외국항공사 수송현황 20200321.xlsx
# 양양공항 외국항공사 수송현황 20200322.xlsx
# 양양공항 외국항공사 수송현황 20200323.xlsx
# 양양공항 외국항공사 수송현황 20200324.xlsx
# 양양공항 외국항공사 수송현황 20200325.xlsx
# 양양공항 외국항공사 수송현황 20200326.xlsx
# 양양공항 외국항공사 수송현황 20200327.xlsx
# 양양공항 외국항공사 수송현황 20200328.xlsx
# 양양공항 외국항공사 수송현황 20200329.xlsx
# 양양공항 외국항공사 수송현황 20200330.xlsx
# 양양공항 외국항공사 수송현황 20200331.xlsx
# 양양공항 국내항공사 수송현황 20200401.xlsx
# 양양공항 국내항공사 수송현황 20200402.xlsx
# 양양공항 국내항공사 수송현황 20200403.xlsx
# 양양공항 국내항공사 수송현황 20200404.xlsx
# 양양공항 국내항공사 수송현황 20200405.xlsx
# 양양공항 국내항공사 수송현황 20200406.xlsx
# 양양공항 국내항공사 수송현황 20200407.xlsx
# 양양공항 국내항공사 수송현황 20200408.xlsx
# 양양공항 국내항공사 수송현황 20200409.xlsx
# 양양공항 국내항공사 수송현황 20200410.xlsx
# 양양공항 국내항공사 수송현황 20200411.xlsx
# 양양공항 국내항공사 수송현황 20200412.xlsx
# 양양공항 국내항공사 수송현황 20200413.xlsx
# 양양공항 국내항공사 수송현황 20200414.xlsx
# 양양공항 국내항공사 수송현황 20200415.xlsx
# 양양공항 국내항공사 수송현황 20200416.xlsx
# 양양공항 국내항공사 수송현황 20200417.xlsx
# 양양공항 국내항공사 수송현황 20200418.xlsx
# 양양공항 국내항공사 수송현황 20200419.xlsx
# 양양공항 국내항공사 수송현황 20200420.xlsx
# 양양공항 국내항공사 수송현황 20200421.xlsx
# 양양공항 국내항공사 수송현황 20200422.xlsx
# 양양공항 국내항공사 수송현황 20200423.xlsx
# 양양공항 국내항공사 수송현황 20200424.xlsx
# 양양공항 국내항공사 수송현황 20200425.xlsx
# 양양공항 국내항공사 수송현황 20200426.xlsx
# 양양공항 국내항공사 수송현황 20200427.xlsx
# 양양공항 국내항공사 수송현황 20200428.xlsx
# 양양공항 국내항공사 수송현황 20200429.xlsx
# 양양공항 국내항공사 수송현황 20200430.xlsx
# 양양공항 외국항공사 수송현황 20200401.xlsx
# 양양공항 외국항공사 수송현황 20200402.xlsx
# 양양공항 외국항공사 수송현황 20200403.xlsx
# 양양공항 외국항공사 수송현황 20200404.xlsx
# 양양공항 외국항공사 수송현황 20200405.xlsx
# 양양공항 외국항공사 수송현황 20200406.xlsx
# 양양공항 외국항공사 수송현황 20200407.xlsx
# 양양공항 외국항공사 수송현황 20200408.xlsx
# 양양공항 외국항공사 수송현황 20200409.xlsx
# 양양공항 외국항공사 수송현황 20200410.xlsx
# 양양공항 외국항공사 수송현황 20200411.xlsx
# 양양공항 외국항공사 수송현황 20200412.xlsx
# 양양공항 외국항공사 수송현황 20200413.xlsx
# 양양공항 외국항공사 수송현황 20200414.xlsx
# 양양공항 외국항공사 수송현황 20200415.xlsx
# 양양공항 외국항공사 수송현황 20200416.xlsx
# 양양공항 외국항공사 수송현황 20200417.xlsx
# 양양공항 외국항공사 수송현황 20200418.xlsx
# 양양공항 외국항공사 수송현황 20200419.xlsx
# 양양공항 외국항공사 수송현황 20200420.xlsx
# 양양공항 외국항공사 수송현황 20200421.xlsx
# 양양공항 외국항공사 수송현황 20200422.xlsx
# 양양공항 외국항공사 수송현황 20200423.xlsx
# 양양공항 외국항공사 수송현황 20200424.xlsx
# 양양공항 외국항공사 수송현황 20200425.xlsx
# 양양공항 외국항공사 수송현황 20200426.xlsx
# 양양공항 외국항공사 수송현황 20200427.xlsx
# 양양공항 외국항공사 수송현황 20200428.xlsx
# 양양공항 외국항공사 수송현황 20200429.xlsx
# 양양공항 외국항공사 수송현황 20200430.xlsx
# 양양공항 국내항공사 수송현황 20200501.xlsx
# 양양공항 국내항공사 수송현황 20200502.xlsx
# 양양공항 국내항공사 수송현황 20200503.xlsx
# 양양공항 국내항공사 수송현황 20200504.xlsx
# 양양공항 국내항공사 수송현황 20200505.xlsx
# 양양공항 외국항공사 수송현황 20200501.xlsx
# 양양공항 외국항공사 수송현황 20200502.xlsx
# 양양공항 외국항공사 수송현황 20200503.xlsx
# 양양공항 외국항공사 수송현황 20200504.xlsx
# 양양공항 외국항공사 수송현황 20200505.xlsx
# C:\Users\admin\Anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# 내항입항 201912 - 1.xlsx
# 내항입항 201912 - 2.xlsx
# 내항입항 202001 - 1.xlsx
# 내항입항 202001 - 2.xlsx
# 내항입항 202002 - 1.xlsx
# 내항입항 202002 - 2.xlsx
# 내항입항 202003 - 1.xlsx
# 내항입항 202003 - 2.xlsx
# 내항입항 202004 - 1.xlsx
# 내항입항 202004 - 2.xlsx
# 내항입항 202005 - 1.xlsx
# 외항입항 201912 - 1.xlsx
# 외항입항 201912 - 2.xlsx
# 외항입항 202001 - 1.xlsx
# 외항입항 202001 - 2.xlsx
# 외항입항 202002 - 1.xlsx
# 외항입항 202002 - 2.xlsx
# 외항입항 202003 - 1.xlsx
# 외항입항 202003 - 2.xlsx
# 외항입항 202004 - 1.xlsx
# 외항입항 202004 - 2.xlsx
# 외항입항 202005 - 1.xlsx
# 입항.csv
# ---------------------------------------------------------------------------
# XLRDError                                 Traceback (most recent call last)
# <ipython-input-10-28ea0af0c0d6> in <module>
# ----> 1 Concat_All()
#
# <ipython-input-9-71c8af809df7> in Concat_All()
#       2
#       3     Preprocessing_Flight()
# ----> 4     Preprocessing_Ship()
#       5     Preprocessing_Confirm()
#       6     Preprocessing_News()
#
# <ipython-input-8-be191c85e4ad> in Preprocessing_Ship()
#      14         print(filename)
#      15
# ---> 16         tmp_df = pd.read_excel(file, header=12)
#      17         tmp_df.columns = column
#      18         df = pd.concat([df,tmp_df])
#
# ~\Anaconda3\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     302
#     303     if not isinstance(io, ExcelFile):
# --> 304         io = ExcelFile(io, engine=engine)
#     305     elif engine and engine != io.engine:
#     306         raise ValueError(
#
# ~\Anaconda3\lib\site-packages\pandas\io\excel\_base.py in __init__(self, io, engine)
#     819         self._io = stringify_path(io)
#     820
# --> 821         self._reader = self._engines[engine](self._io)
#     822
#     823     def __fspath__(self):
#
# ~\Anaconda3\lib\site-packages\pandas\io\excel\_xlrd.py in __init__(self, filepath_or_buffer)
#      19         err_msg = "Install xlrd >= 1.0.0 for Excel support"
#      20         import_optional_dependency("xlrd", extra=err_msg)
# ---> 21         super().__init__(filepath_or_buffer)
#      22
#      23     @property
#
# ~\Anaconda3\lib\site-packages\pandas\io\excel\_base.py in __init__(self, filepath_or_buffer)
#     351             self.book = self.load_workbook(filepath_or_buffer)
#     352         elif isinstance(filepath_or_buffer, str):
# --> 353             self.book = self.load_workbook(filepath_or_buffer)
#     354         elif isinstance(filepath_or_buffer, bytes):
#     355             self.book = self.load_workbook(BytesIO(filepath_or_buffer))
#
# ~\Anaconda3\lib\site-packages\pandas\io\excel\_xlrd.py in load_workbook(self, filepath_or_buffer)
#      34             return open_workbook(file_contents=data)
#      35         else:
# ---> 36             return open_workbook(filepath_or_buffer)
#      37
#      38     @property
#
# ~\Anaconda3\lib\site-packages\xlrd\__init__.py in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     155         formatting_info=formatting_info,
#     156         on_demand=on_demand,
# --> 157         ragged_rows=ragged_rows,
#     158     )
#     159     return bk
#
# ~\Anaconda3\lib\site-packages\xlrd\book.py in open_workbook_xls(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#      90         t1 = perf_counter()
#      91         bk.load_time_stage_1 = t1 - t0
# ---> 92         biff_version = bk.getbof(XL_WORKBOOK_GLOBALS)
#      93         if not biff_version:
#      94             raise XLRDError("Can't determine file's BIFF version")
#
# ~\Anaconda3\lib\site-packages\xlrd\book.py in getbof(self, rqd_stream)
#    1276             bof_error('Expected BOF record; met end of file')
#    1277         if opcode not in bofcodes:
# -> 1278             bof_error('Expected BOF record; found %r' % self.mem[savpos:savpos+8])
#    1279         length = self.get2bytes()
#    1280         if length == MY_EOF:
#
# ~\Anaconda3\lib\site-packages\xlrd\book.py in bof_error(msg)
#    1270
#    1271         def bof_error(msg):
# -> 1272             raise XLRDError('Unsupported format, or corrupt file: ' + msg)
#    1273         savpos = self._position
#    1274         opcode = self.get2bytes()
#
# XLRDError: Unsupported format, or corrupt file: Expected BOF record; found b'\xed\x95\xad\xeb\xaa\x85,\xed'
